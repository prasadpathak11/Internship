# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv ("avocado.csv",parse_dates=["Date"])
df.head(10)
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0           0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4 2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5 2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6 2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7 2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8 2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9 2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
# 5   43.61     6683.91     6556.47      127.44          0.0  conventional
# 6   93.26     8318.86     8196.81      122.05          0.0  conventional
# 7   80.00     6829.22     6266.85      562.37          0.0  conventional
# 8   85.34    11388.36    11104.53      283.83          0.0  conventional
# 9  113.00     8625.92     8061.47      564.45          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany
# 5  2015  Albany
# 6  2015  Albany
# 7  2015  Albany
# 8  2015  Albany
# 9  2015  Albany

# %%
parse_dates=['Date']

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.dtypes
#  here now the 'Date' column , earlier which is showing as an 'object' datatype, now after parsing date it is converted into..
#  datetime formate.
# Out:
# Unnamed: 0               int64
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
#  here the column "unnamed" having no relevance with the dataset, it is just having indexing numbers.
#  so we have to drop this irrelevent column form the dataset.

# %%
df.columns
#  here we can see that the above mentioned column is now removed successfully.
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
#  here as above we can see that in the name of the columns, there are also some capital alphabets are also present...
#  now simpler use we have make it all in small latter capitls..

# %%
column = ['date', 'average price', 'total volume', '4046', '4225', '4770', 'total bags','small bags','large bags','xlarge bags','type','year','region']

# %%
df.columns=column

# %%
df.head(5)
# here below we have changed all column names into small characters, and also one column is dropped.
# Out:
#         date  average price  total volume     4046       4225    4770  \
# 0 2015-12-27           1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20           1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13           0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06           1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29           1.28      51039.60   941.48   43838.39   75.78
#
#    total bags  small bags  large bags  xlarge bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.shape
# here we identifying the shape of our dataset whic is having  18249 ROWS & 13 COLUMNS
# Out:
# (18249, 13)

# %%
df.info()
#  here we can see that
# 1) total number for columns present : 13
# 2) total number of rows presnet : 18,249
# 3) total "data types present in data set" : 4 (i.e "datetime64[ns](1), float64(9), int64(1), object(2)")
# 4)NULL VALUES are may not be present in our dataset.
#    because there is no difference between the total count and present values.
#  5) So we can also to check 'null values' & 'whitespaces' in our dataset by futher different methods..
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           18249 non-null  datetime64[ns]
#  1   average price  18249 non-null  float64
#  2   total volume   18249 non-null  float64
#  3   4046           18249 non-null  float64
#  4   4225           18249 non-null  float64
#  5   4770           18249 non-null  float64
#  6   total bags     18249 non-null  float64
#  7   small bags     18249 non-null  float64
#  8   large bags     18249 non-null  float64
#  9   xlarge bags    18249 non-null  float64
#  10  type           18249 non-null  object
#  11  year           18249 non-null  int64
#  12  region         18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# CHECKING NULL VALUES ==========================================================================================================

# %%
df.isnull().sum()
#  here by following, we can clearly says that , there is NO NULL value is present in out dataset.
# Out:
# date             0
# average price    0
# total volume     0
# 4046             0
# 4225             0
# 4770             0
# total bags       0
# small bags       0
# large bags       0
# xlarge bags      0
# type             0
# year             0
# region           0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.isnull())

# here with the help of heatmap also we can see that there is not any presence of null values in the given dataset.
# Out:
# <AxesSubplot:>

# %% [markdown]
# CHECKING UNIQUE VALUES & PERFORMING UNIVARIATE ANALYSIS FOR EACH COLUMN ===================================================================================================================

# %%
df.nunique()
#  here we can find the number of unique values in each column.
# as we know that there are total 18,249 rows are present in the given dataset.
# and here we can see that the column which consist very less number of unique value is 'type(2)' 'year(4)' 'region(54)' ...
# ... so we can say that the above mentioned columns are 'Categorical Columns'
# here we can see that 'date' & 'average price' is also having very less unique numbers as compared to the total no. of rows.
# Out:
# date               169
# average price      259
# total volume     18237
# 4046             17702
# 4225             18103
# 4770             12071
# total bags       18097
# small bags       17321
# large bags       15082
# xlarge bags       5588
# type                 2
# year                 4
# region              54
# dtype: int64

# %%
# 1) Analysing DATE column-1 ====>>

# %%
df['date'].nunique()
#  total 169 unique dates are present in the column, out of 18,249 rows
# Out:
# 169

# %%
df['date'].value_counts()
# Out:
# 2015-12-27    108
# 2017-12-24    108
# 2017-12-10    108
# 2017-12-03    108
# 2017-11-26    108
#              ...
# 2016-11-06    108
# 2018-01-07    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: date, Length: 169, dtype: int64

# %%
df['date'].value_counts().min()

# the minimum values assigned for any date is 107
# Out:
# 107

# %%
df['date'].value_counts().max()
# and the maximum values assigned for any date is 108
# that means all of 169 unique dates are having values upto 107 or 108.
# Out:
# 108

# %%
# 2) Analysing Average Price column =====>>

# %%
df['average price'].nunique()
# out of 18,249 rows , there are 259 unique average prices are present in the column.
# Out:
# 259

# %%
df['average price'].value_counts()
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: average price, Length: 259, dtype: int64

# %%
df['average price'].value_counts().min()
#  the minimum assigned value for any average price is '1'
# Out:
# 1

# %%
df['average price'].min()
#  the Minimum average price present in the column is '0.44'
# Out:
# 0.44

# %%
df['average price'].value_counts().max()
#  the maximum value assigned for any average price is '202'
# Out:
# 202

# %%
df['average price'].max()
#  the Maximum average price present in the column is '3.25'
# Out:
# 3.25

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('1- Analysing Average Price')
sns.boxplot(x='average price', data=df)
plt.xlabel('Average price', fontsize = 10)
plt.xticks(rotation=0,ha ='right')
# plt.ylabel('no. of counts', fontsize = 10)
plt.yticks(rotation=0, ha = 'center')
plt.show()

#  here from the below boxplot we can find that , 
#  The Minimum Average Price is below = 0.5 (i.e- 0.44)
#  The Maximum Average Price is Higher then = 3.0 (i.e- 3.25)
#  & most of the average prices are present in between (1.0 - 1.7)
# there may be presence of OUTLIERS in the following column.

# %%
plt.figure(figsize = (5,4), facecolor='white')
plt.title('2- Analysing Average Price')
sns.distplot(df['average price'])
plt.xlabel('Average Price', fontsize = 10)
plt.xticks(rotation=0,ha ='center')
plt.ylabel('no. of counts', fontsize = 10)
# plt.yticks(rotation=0, ha = 'center')
plt.show()

# here with the help of distribution plot also we can clearly see that the most of the values present in between (1.0 - 1.7)....
# .....as we have mentioned above also
#  here from the below distribution plot we can say that the data is 'RIGHT SKEWED' that means there may be presence of outliers

# %%
plt.figure(figsize = (6,4), facecolor='white')
plt.title('2- Analysing Average Price')
sns.scatterplot(df.index,df['average price'])
plt.xlabel('No. of Data Present', fontsize = 10)
# plt.xticks(rotation=0,ha ='center')
plt.ylabel('no. of counts', fontsize = 10)
# plt.yticks(rotation=0, ha = 'center')
plt.show()

#  here in the below scatterplot we can find that the NO. OF AVERAGE PRICE is INCREASING 
#  The most of the Data is present in between the Average price of 1.0 -to- 2.5

# %%
#  3) Analysing Total Volumn column ====>>

# %%
df['total volume'].nunique()
# outof 18,249 , there 18,237 unique values are present in the column, that means there are no unique values.
# Out:
# 18237

# %%
df['total volume'].min()
# Minimum 'total volume' vlaue prresent in the column is = 84.56
# Out:
# 84.56

# %%
df['total volume'].max()
#  Maximum 'total volume' value present in the column is = 62505646.52
# Out:
# 62505646.52

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('3- Analysing Total Volume')
sns.boxplot(x='total volume', data=df)
plt.xlabel('Total Volume', fontsize = 10)
plt.xticks(rotation=0,ha ='right')
# plt.ylabel('no. of counts', fontsize = 10)
plt.yticks(rotation=0, ha = 'center')
plt.show()

#  It is very difficult to make any statement with the help of following plot.
#  but from below boxplot we can surely say that , there is the PRESENCE OF OUTLIERS in the column

# %%
plt.figure(figsize = (5,4), facecolor='white')
plt.title('3- Analysing Total Volume')
sns.distplot(df['total volume'])
plt.xlabel('Total Volume', fontsize = 10)
plt.xticks(rotation=0,ha ='center')
plt.ylabel('no. of counts', fontsize = 10)
# plt.yticks(rotation=0, ha = 'center')
plt.show()

# here with the help of distribution plot also we can clearly see that the most of the values present in between (0 - 1)....
#  here from the below distribution plot we can say that the data is 'VERY MUCH RIGHT SKEWED' that means....
# ...there may be presence of outliers

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('3- Analysing Total Volume')
sns.stripplot(x=df['total volume'])
plt.xlabel('Total Volume Range', fontsize=10)
plt.show()
# here in the below stripplot graph we can clearly see that the 'Total Volume' is very DENSE in the range of 0-1
# and the volume is SCATTERED IN THE RANGE OF 2 - 5.
#  above 5, there may be presence of outliers

# %%
plt.figure(figsize = (6,4), facecolor='white')
plt.title('3- Analysing Total Volume')
sns.scatterplot(df.index,df['total volume'])
# plt.xlabel('Total Volume', fontsize = 10)
# plt.xticks(rotation=0,ha ='center')
# plt.ylabel('no. of counts', fontsize = 10)
# plt.yticks(rotation=0, ha = 'center')
plt.show()

#  here in the below scatterplot we can find that the maximum no. of total volume ranges between 0-1

# %%
(df['total volume']>100000).value_counts()
# here below we can find that the value count of 'total volume' above 1 lakh is 9,301
#                                                              & below is = 8,948
# Out:
# True     9301
# False    8948
# Name: total volume, dtype: int64

# %%
# 4) Analysing LPU 4046 (Product Lookup Code) =====>>

# %%
df['4046'].unique()
# Out:
# array([1036.74,  674.28,  794.7 , ..., 1191.92, 1527.63, 2894.77])

# %%
df['4046'].nunique()
# out of 18249, there are 17,702 unique values are present in the column, which shows that it is not a categorical column.
# Out:
# 17702

# %%
df['4046'].min()
# the minimum value is 0.0
# Out:
# 0.0

# %%
df['4046'].max()
#  the maximum value or quantity is 22743616.17
# Out:
# 22743616.17

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('4- Analysing Avocado code 4046 sales')
sns.stripplot(x=df['4046'])
plt.xlabel('Avocado Product Code 4046', fontsize=10)
plt.show()
# here in the below stripplot graph we can clearly see that the 'product 4046' is very DENSE in the range of 0-0.5
# and the volume is SCATTERED IN THE RANGE OF 0.7 - 1.5
#  above 2.0, there may be presence of outliers

# %%
#  5) Analysing Avocado Product Code 4225 ====>>

# %%
df['4225'].nunique()
# out of 18,249 , there are 18,103 unique values are present, which meant it ia not a categorical column.
# Out:
# 18103

# %%
df['4225'].min()
# Out:
# 0.0

# %%
df['4225'].max()
# Mamimum no. sold  Avocado of -product code-4225
# Out:
# 20470572.61

# %%
plt.figure(figsize=(12,3))
plt.title('5- Analysing Avocado 4225 sales')
sns.boxenplot(data=df, x='4225')
plt.xlabel('Sales Distribution of Avocado-4225')
plt.show()

# here in the below 'boxenplot' we can see the distributioin of sales of 'AVOCADO-4225'.
# there may be presence of outliers in this column.

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('5- Analysing Avocado code 4225')
sns.stripplot(x=df['4225'])
plt.xlabel('Avocado Product Code 4225', fontsize=10)
plt.show()
# here in the below stripplot graph we can clearly see that the 'product 4225' is very DENSE in the range of 0-0.5
# and the volume is SCATTERED IN THE RANGE OF 0.7 - 1.5
#  above 1.5, there may be presence of outliers

# %%
#  6) Analysing Avocado-4770 sales ======>>

# %%
df['4770'].nunique()
# outof 18,249, there are 12,071 unique values are present in the columns, but we can't say this is a categorical column.
# Out:
# 12071

# %%
df['4770'].min()
# Out:
# 0.0

# %%
df['4770'].max()
# Out:
# 2546439.11

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('6- Analysing Avocado-4770')
sns.stripplot(x=df['4770'])
plt.xlabel('Avocado Product Code 4770', fontsize=10)
plt.show()
# here in the below stripplot graph we can clearly see that the 'product 4770' is very DENSE in the range of 0-0.5
# and the volume is SCATTERED IN THE RANGE OF 0.5 - 2.0
#  above 2.5, there may be presence of outliers

# %%
plt.figure(figsize=(12,3))
plt.title('6- Analysing Avocado 4770 sales distribution')
sns.boxenplot(data=df, x='4770')
plt.xlabel('Sales Distribution of Avocado-4770')
plt.show()

# here in the below 'boxenplot' we can see the distributioin of sales of 'AVOCADO-4225'.
# there may be presence of outliers in this column.

# %%
plt.figure(figsize = (6,4), facecolor='white')
plt.title('6- Analysing Avocado-4770 sales distribution')
sns.scatterplot(df.index,df['4770'])
plt.xlabel('Sales Distribution Of Avocado-4770', fontsize = 10)
# plt.xticks(rotation=0,ha ='center')
# plt.ylabel('no. of counts', fontsize = 10)
# plt.yticks(rotation=0, ha = 'center')
plt.show()

#  here in the below scatterplot we can find that the NO. OF Avocado-4770 sales

# %%
#  7) Analysing Total Bag's Column ====>>

# %%
df['total bags'].unique()
# Out:
# array([ 8696.87,  9505.56,  8145.35, ...,  9394.11, 10969.54, 12014.15])

# %%
df['total bags'].nunique()
#  it is not a categorical column, because out of 18,249, there are 18,097 unique no. of values are present in the column.
# Out:
# 18097

# %%
df['total bags'].min()
# Out:
# 0.0

# %%
df['total bags'].max()
# the Maximum no. of total bags of AVOCADO sold is - 1,93,73,134.37
# Out:
# 19373134.37

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('7- Analysing Total Bags Sales')
sns.boxplot(x='total bags', data=df)
# plt.xlabel('Total Volume', fontsize = 10)
# plt.xticks(rotation=0,ha ='right')
# plt.ylabel('no. of counts', fontsize = 10)
# plt.yticks(rotation=0, ha = 'center')
plt.show()

#  It is very difficult to make any statement with the help of following plot.
#  but from below boxplot we can surely say that , there is the PRESENCE OF OUTLIERS in the column

# %%
plt.figure(figsize=(12,3))
plt.title('7- Analysing Total Bags Sales')
sns.boxenplot(data=df, x='total bags')
plt.xlabel('Sales Distribution of Total no. of Bags')
plt.show()

# here in the below 'boxenplot' we can see the distributioin of sales of 'AVOCADO-4225'.
# there may be presence of outliers in this column.

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('7- Analysing Total Bags Sales')
sns.stripplot(x=df['total bags'])
plt.xlabel('Total Bags Sold', fontsize=10)
plt.show()
# here in the below stripplot graph we can clearly see that the 'Total Bags Sold' is very DENSE in the range of 0 -to- 0.25
# and the volume is SCATTERED IN THE RANGE OF 0.50 - 1.50
#  above 1.75, there may be presence of outliers

# %%
# 8) Analysing Small Bag sale ====>>

# %%
df['small bags'].nunique()
#  out of 18,249, there are 17,321 no. of unique values are present in the column.
# so it is not consider as a categorical column.
# Out:
# 17321

# %%
df['small bags'].min()
# Out:
# 0.0

# %%
df['small bags'].max()
#  the maximum no. of small bag sales is = 1,33,84,586.8
#  As above we have seen that the TOTAL BAGS SALE IS = 1,93,73,134.37, OUTOF which only SMALL BAGS SALE IS = 1,33,84,586.8  ...
# .... which is a very huge amount.
# Out:
# 13384586.8

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('8- Analysing Small Bags Sales')
sns.stripplot(x=df['small bags'])
plt.xlabel('Small Bags Sales', fontsize=10)
plt.show()
# here in the below stripplot graph we can clearly see that the 'small bag sales' is very DENSE in the range of 0 -to- 0.25
# and the volume is SCATTERED IN THE RANGE OF 0.25 - 1.2
#  above 1.2, there may be presence of outliers

# %%
plt.figure(figsize = (5,4), facecolor='white')
plt.title('8- Analysing Small Bags Sales')
sns.distplot(df['small bags'])
plt.xlabel('Small Bags Sales', fontsize = 10)
plt.xticks(rotation=0,ha ='center')
# plt.ylabel('no. of counts', fontsize = 10)
# plt.yticks(rotation=0, ha = 'center')
plt.show()

# here with the help of distribution plot also we can clearly see that the DENSITY is verymuch Higher in the range of 0 - 0.2

# %%
#  9) Analysing Large Bags Sales ======>>>>

# %%
df['large bags'].nunique()
# there are 15,082 no. of unique values are present out of total 18,249 values
#  not consider as a categorical column.
# Out:
# 15082

# %%
df['large bags'].min()
# Out:
# 0.0

# %%
df['large bags'].max()
# out of TOTAL BAGS SALES = 1,93,73,134.37,  57,19,096 Sales is of LARGE BAGS ONLY
# Out:
# 5719096.61

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('9- Analysing Large Bags Sales')
sns.stripplot(x=df['large bags'])
plt.xlabel('Large Bags Sales', fontsize=10)
plt.show()
# here in the below stripplot graph we can clearly see that the 'Large bag sales' is very DENSE in the range of 0 -to- 1.5
# and the volume/density is SCATTERED IN THE RANGE OF 1.5 - 4
#  above 4, there may be presence of outliers

# %%
# 10) Analysing Xtra Large Bags Sales =====>>>

# %%
df['xlarge bags'].unique()
# Out:
# array([  0.  ,  33.33, 104.17, ..., 228.27,  12.12,  24.18])

# %%
df['xlarge bags'].nunique()
# 5588 no. of unique values are present in the column, out of 18,249
# not considered as a categorical column.
# Out:
# 5588

# %%
df['xlarge bags'].value_counts()
# out of 18,249 , 12,048 values are present in 0.00 quantity
# Out:
# 0.00       12048
# 3.33          29
# 6.67          16
# 1.11          15
# 5.00          12
#            ...
# 3018.05        1
# 2739.44        1
# 9301.67        1
# 8640.00        1
# 24.18          1
# Name: xlarge bags, Length: 5588, dtype: int64

# %%
df['xlarge bags'].value_counts().min()
#  minimum value is 1 for any quantity of 'xlarge bags'
# Out:
# 1

# %%
df['xlarge bags'].value_counts().max()
#  maximum quantity is at 0.00 value
# Out:
# 12048

# %%
plt.figure(figsize = (12,1), facecolor='white')
plt.title('10- Analysing XLarge Bags Sales')
sns.stripplot(x=df['xlarge bags'])
plt.xlabel('XLarge Bags Sales', fontsize=10)
plt.show()
# here in the below stripplot graph we can clearly see that the 'Xtra Large bag sales' is very DENSE in the range of 0 -to- 1 lakh
# and the volume/density is SCATTERED IN THE RANGE OF 1 lakh - 4 lakh
#  above 4, there may be presence of outliers

# %%
(df['xlarge bags']>100000).value_counts()
#  above 1 lakh only 87 no. of quantities are present
# and below this 18,162 total qunatities are present, if we deduct 12,048 quantities which are at the 0th value, then .....
#  ... below 1 lakh remaining only = 6,114 X-Large Bags are Sold
# Out:
# False    18162
# True        87
# Name: xlarge bags, dtype: int64

# %%
# 11) Analysing Types of Avocado ====>>>

# %%
df['type'].unique()
# here we can find that there are two types are present which is - CONVENTIONAL & ORGANIC
# which is the types of AVOCADO FRUIT, that they are ORGANIC Or CONVENTIONAL
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df['type'].nunique()
# Out:
# 2

# %%
df['type'].value_counts()
# both categories are having equivalent values
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
plt.figure (figsize = (4,2), facecolor = "white")
plt.title('11. Analysing Types Of Avocado')
sns.countplot(x='type', data = df)
plt.xlabel('\nTypes Of Avocado', fontsize=10)
# plt.xticks(rotation=30, ha = 'right')
plt.ylabel('COUNTS',fontsize=10)
# plt.yticks(rotation=30, ha = 'right')

# Here we can see that the most of counts are present in category 'A' & 'A-'.
# as above also we find the same in numerical form.  
#  similarly we can also find same for all other columns.
# Out:
# Text(0, 0.5, 'COUNTS')

# %%
#  12) Analysing Year column =====>

# %%
df['year'].unique()
# the data which is available for the year of 2015,2016,2017 & 2018
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
df['year'].nunique()
# Out:
# 4

# %%
# 13) Analysing Regions =====>

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df['region'].nunique()
# there are 54 Regions are present in the column
# Out:
# 54

# %% [markdown]
# ========================== upto here UNIVARIATE ANALYSIS FOR EACH COLUMN IS COMPLETED ===============================

# %% [markdown]
# ============ Now Movng Forward Looking For BIVRIATE & MULTI-VARIATE ANALYSIS ===========================================

# %%
df.head(5)
# Out:
#         date  average price  total volume     4046       4225    4770  \
# 0 2015-12-27           1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20           1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13           0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06           1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29           1.28      51039.60   941.48   43838.39   75.78
#
#    total bags  small bags  large bags  xlarge bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
sns.pairplot(data=df, vars=['total volume','4046', '4225', '4770'])
plt.suptitle('Pair Plot (Pairwise Relationships)')
plt.show()

# Here with the help of PAIRPLOT we are analysing TOTAL VOLUME with - '4046' - '4225' - '4770'
# here in the below SCATTER PLOT  we find the distribution of all three different varities of AVOCADO with Total Volume.

# %%
df.head(2)
# Out:
#         date  average price  total volume     4046      4225   4770  \
# 0 2015-12-27           1.33      64236.62  1036.74  54454.85  48.16
# 1 2015-12-20           1.35      54876.98   674.28  44638.81  58.33
#
#    total bags  small bags  large bags  xlarge bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany

# %%
# 1) Analysing Average price v/s Total Volumne ======>>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n1. Analysing Average Price with Total volume\n')
sns.scatterplot (x= 'total volume', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\nTotal Volume ')
plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can clearly find that the Average price is Higher , in between the volume of 0-1 range.
# and the Average Price is REDUCING as the no. of volume increses.

# %%
#  2) Analysing Average Price with Avocado-4046 ====>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n2. Analysing Average Price with Avocado-4046 \n')
sns.scatterplot (x= '4046', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\nAvocado -4046 Volume ')
plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can clearly find that the Average price is Higher , in between the volume of 0-0.5 range.
# and the Average Price is REDUCING as the no. of volume increses.
# HERE WE GETTING SAME GRAPH AS ABOVE GRAPH OF ' TOTAL VOLUME', THE RESION BEHIND THIS IS .....IN THE TOTAL VOLUME, THE MOST....
# ... FO THE QUANTITY IS OF AVOCADO-4046 SALES. which is already mentioned above in the univariate analysis..

# %%
#  3) Analysing Average price with Avocad-4225  =====>>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n3. Analysing Average Price with Avocado-4225\n')
sns.scatterplot (x= '4225', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\nAvocado-4225 Volume ')
plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can clearly find that the Average price is Higher , in between the volume of 0-.5 range.
# and the Average Price is REDUCING with the INCREASING IN NO. OF VOLUME OF AVOCADO-4225
# here we can also find that the DENSITY OF VOLUME is HIGHER in the 0.0 -to- 0.5 volume range.

# %%
# 4) Analysing Average Price with Total bags sales =====>>>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n4. Analysing Average Price with Sales of Total Bags\n')
sns.scatterplot (x= 'total bags', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\nTotal Bags Sales ')
plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can clearly find that the Average price is Higher , in between the volume of 0-.50 range.
# and the Average Price is REDUCING with the INCREASING IN NO. OF VOLUME OF Total Bags Sales.
# here we can also find that the DENSITY OF Total bags sale  is HIGHER in the 0.0 -to- 0.50 range.

# %%
# 5) Analysing Average Price with Small Bags sales ====>>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n5. Analysing Average Price with Sales of small Bags\n')
sns.scatterplot (x= 'small bags', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\nSmall Bags Sales ')
plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can clearly find that the Average price is Higher , in between the volume of 0-.20 range.
# and the Average Price is REDUCING with the INCREASING IN NO. OF VOLUME OF Small Bags Sales.
# here we can also find that the DENSITY OF Small bags sale  is HIGHER in the 0.0 -to- 0.20 range....
# ....but it is also SCATTERED upto 1.4

# %%
# 6) Analysing Average Price with Large Bags Sales ======>>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n6. Analysing Average Price with Sales of Large Bags\n')
sns.scatterplot (x= 'large bags', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\nLarge Bags Sales ')
plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can clearly find that the Average price is Higher , in between the volume of 0-1 range.
# Here we can find an intresting fact the AVERAGE PRICE is NOT MUCH REDUCING with the INCRESING VOLUME.
#  It may be due to , sales of LARGE BAGS is not much as compared to SMALL BAGS

# %%
# 7) Analysing Average Price with X-Large Bags sales =====>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n7. Analysing Average Price with Sales of X-Large Bags\n')
sns.scatterplot (x= 'xlarge bags', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\nX-Large Bags Sales ')
plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can clearly find that the Average price is Higher , in between the volume of 0-1 lakh range.
# Here we can find an intresting fact the AVERAGE PRICE is NOT MUCH REDUCING with the INCRESING VOLUME.
#  It may be due to , sales of X-LARGE BAGS is not much as compared to LARGE BAGS
# there may be presence of OUTLIERS near 5 lakh quantity
# we can see that the DENSITY is deacresing from 0 to 5 lakh quanity of sales.

# %%
# 8) Analysing Average Price with type ======>>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n8. Analysing Average Price with Avocado Type\n')
sns.barplot (x= 'type', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\n Types  ')
# plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can clearly find that the Average price of 'ORAGNIC AVOCADOS' is MUCH MORE HIGHER THEN 'CONVENTIONAL AVOCADOS'
# So here can clearly see the Average price difference between the ORGANIC & CONVENTIONAL AVOCADOS

# %%
# 9) Analysing Average Price with year ====>>>

# %%
plt.figure (figsize = (6,3), facecolor = "white")
plt.title('\n9. Analysing Year Wise Average Price of AVOCADOS\n')
sns.barplot (x= 'year', y = 'average price', data= df, palette = "bright")
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\n Years ')
plt.xticks (rotation = 0, ha= 'right')
plt.ylabel('Average Price')
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can that the Average prices are Higher in the year 2017.
#  whereas in 2015, 2016 & 2018 the Average Prices are Almost Same.

# %%
# 10) Analysing Region wise Average price of avocados ======>>>>

# %%
plt.figure (figsize = (20,6), facecolor = "white")
plt.title('\n10. Analysing Region Wise Average Price of AVOCADOS\n', fontsize = 20)
sns.barplot (x= 'region', y = 'average price', data= df, palette='ch:start=.2,rot=-.4')
# plt.xticks(rotation=30, ha = 'right')
plt.xlabel('\n Regions ',fontsize=15)
plt.xticks (rotation = 90, ha= 'center',fontsize=12)
plt.ylabel('Average Price',fontsize=15)
# plt.yticks (rotation = 0, ha='center')
# plt.legend(loc= 'center', fontsize=6)
plt.show()

#  here we can that the Average prices of avocados are lying in betweeen 1.25 -to- 1.50 range
#  but in few of the regions average prices are higher, 
# like = 'HartfordSpringfield', 'SanFrancisco', 'NEWYORK', 'NORTHEAST','PHILADELPHIA'
# & the Lowest avverage prices are in = 'DALLSFTWORTH','HOUSTON','PHOENIXTUCSON','SOUTHCENTRAL'

# %%
# 11) Analysing Type wise Total Sales of Avocados ====>>>

# %%
plt.figure(figsize=(5,5))
plt.title('\n 11. Analysing Type Wise Sales Of Avocaods')
plt.pie(df['type'].value_counts(),startangle=90,autopct='%.3f',labels=['conventional', 'organic'],shadow= True)
plt.show()

# here in the below pie plot we can fidn that the sales of both CONVENTIONAL & ORGANIC both are almost similar.

# %%
# 12) Analysing Average Price according to Bags size =====>>>>

# %%
plt.figure(figsize=(8,5))
plt.title('\n12. Average Price Analysis for Multiple Bag Size\n')
sns.lineplot (data=df, x='average price', y='small bags', label = '1. small bags avg. price')
sns.lineplot (data=df, x='average price', y='large bags', label = '2. large bags avg. price')
sns.lineplot (data=df, x='average price', y='xlarge bags', label = '3. xlarge bags avg. price')
plt.xlabel('Average Price')
plt.ylabel('Different types of Bags')
plt.legend()
plt.show()

# here in the following LINE GRAPH we can clearly see the difference between the AVERAGE PRICES of SMALL, LARGE & XLARGE BAGS
# the Average price for per Avocado in small bags is higher then Large & x-large Bags average price.

# %%
#  12.1 > Analysing the Average Price For the Multiple Avocado Products =====>>>>>

# %%
plt.figure(figsize=(8,5))
sns.lineplot (data=df, x='average price', y='4046', label = '1. avg. price of 4046')
sns.lineplot (data=df, x='average price', y='4225', label = '2. avg. price of 4225')
sns.lineplot (data=df, x='average price', y='4770', label = '3. avg. price of 4770')
plt.xlabel('Average Price')
plt.ylabel('Different Avocado Products')
plt.title('\n12.1> Average Price Analysis for Multiple Avocado Products\n')
plt.legend()
plt.show()

# here in the below LINE GRAPH we can find that the average price for '4046' > '4225' > '4770'
#  it is in the correct manner because we also finds the sales of above products in the same manner.

# %%
# 13) Analysing Sales according to Bag Size ====>>>

# %%
plt.figure(figsize=(10,6))
sns.lineplot (data=df, x='total bags', y='small bags', label = '1. small bags')
sns.lineplot (data=df, x='total bags', y='large bags', label = '2. large bags')
sns.lineplot (data=df, x='total bags', y='xlarge bags', label = '3. xlarge bags')
plt.xlabel('Total Bags Sales')
plt.ylabel('Type Of Bags- Small, Large & XLarge Bags')
plt.title('\n 13. Sales Analysis according to Bag Size')
plt.legend()
plt.show()

# here in the following LINE GRAPH we can find the SALES GROWTH of SMALL, LARGE & X-LARGE BAGS OF AVOCADOS
# here below we can find that the sales growth is : SMALL BAGS > LARGE BAGS > X-LARGE BAGS
# there is HUGE DIFFERENCE BETWEEN the sales of SMALL BAGS & X-LARGE BAGS
# due to which we can conclude that the CUSTOMERS ARE LIKE TO BUY SMALL BAGS as compared to LARGE & X-LARGE BAGS

# %%
# 14) Analysing Sales Volume for Multiple Avocado Prduct

# %%
plt.figure(figsize=(10,6))
sns.lineplot (data=df, x='total volume', y='4046', label = '1. product code- 4046')
sns.lineplot (data=df, x='total volume', y='4225', label = '2. product code- 4225')
sns.lineplot (data=df, x='total volume', y='4770', label = '3. product code- 4770')
plt.xlabel('Total Volulme')
plt.ylabel('Multiple Avocado Products')
plt.title('\n 14. Sales Volume For Multiple Avocado Product')
plt.legend()
plt.show()

#  here below in the LINE GRAPH we find the SALES VOLUME for the MULTIPLE AVOCADO PRODUCTS (4046,4225,4770)
# here below we can find that the sales volume of AVOCADO PRODUCT WITH THE CODE OF - 4046 & 4225 IS SIMILAR & ...
# ....HIGHER AS COMPARED to AVOCADO-4770.
# From this we can conclude that the CUSTOMERS ARE LIKING SVOCADO-4046 & 4225 MORE AS COMPARED TO AVOCADO-4770

# %%
# 14) Analysing Region Wise Sales of Mutiplt Avocado Products ====>>>>

# %%
plt.figure(figsize=(20,8))
plt.title('\n 14. Region Wise Sales Of Multiple Avocado Products',fontsize=20)
sns.lineplot (data=df, x='region', y='4046', label = '1. product code- 4046')
sns.lineplot (data=df, x='region', y='4225', label = '2. product code- 4225')
sns.lineplot (data=df, x='region', y='4770', label = '3. product code- 4770')
plt.xlabel('Total Regions',fontsize=15)
plt.xticks(rotation=90,ha='center',fontsize=12)
plt.ylabel('\nSales of Multiple Avocado Products',fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.show()

#  here below in the LINE GRAPH we find the SALES OF MILTIPLE AVOCADO PRODUCTS
# Here below we can find that the sales of 4770 is LOW as compared to 4225 & 4046 in overall REGIONS.

# the Sales of 4046 & 4225 both are Higher in = 'BuffaloRochester', 'California', 'Charlotte','Tampa', 'TotalUS', 'West', 'WestTexNewMexico'

# the Sales of 4046 is Higher in = 'LasVegas', 'LosAngeles', 'Louisville','Philadelphia','PhoenixTucson', 'Pittsburgh', 
#                                  'Plains', 'Portland','SouthCarolina','SouthCentral', 'Southeast', 'Spokane'

# the Sales of 4225 is Higher in = 'GrandRapids', 'GreatLakes', 'HarrisburgScranton','MiamiFtLauderdale','Midsouth', 'Nashville'
#                                  'NewOrleansMobile', 'NewYork','Northeast', 'NorthernNewEngland'

#  from the above analysis we can conclude that AVOCADO 4046 & 4225 are more liked by CUSTOMERS as compared to AVOCADO-4770

# %%
#  15) Analysing Region Wise Sales of Multiple Size Bags =====>>>

# %%
plt.figure(figsize=(20,8))
plt.title('\n 15. Region Wise Sales Of Multiple Size Bags',fontsize=20)
sns.lineplot (data=df, x='region', y='small bags', label = '1. Small Bags')
sns.lineplot (data=df, x='region', y='large bags', label = '2. Large Bags')
sns.lineplot (data=df, x='region', y='xlarge bags', label = '3. X-Large Bags')
plt.xlabel('Total Regions',fontsize=15)
plt.xticks(rotation=90,ha='center',fontsize=12)
plt.ylabel('\nSales of Multiple Size Bags',fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.show()

#  here below in the LINE GRAPH we find the SALES OF MILTIPLE AVOCADO PRODUCTS
# Here below we can find that the sales of 4770 is LOW as compared to 4225 & 4046 in overall REGIONS.

# the Sales of SMALL ABGS are Higher in = 'BuffaloRochester', 'California', 'Charlotte','SouthCarolina','Tampa',
#                                         'TotalUS', 'West','WestTexNewMexico'
#                                         ,'GrandRapids', 'GreatLakes', 'HarrisburgScranton','LasVegas',
#                                       'LosAngeles', 'Louisville','MiamiFtLauderdale','Midsouth', 'Nashville',
#                                       'NewOrleansMobile', 'NewYork','Northeast', 'NorthernNewEngland',
#                                       'Pittsburgh', 'Plains', 'Portland','RaleighGreensboro','SouthCarolina','SouthCentral',
#                                      'Southeast', 'Spokane'

#  THE HIGHEST SALE OF SMALL & LARGE BAGS ARE IN = 'Tampa', 'TotalUS', 'West', 'WestTexNewMexico' REGION

# %% [markdown]
# =================== UP TO HERE HERE ANALYSIS PART IS COMPLETED ========================================

# %%
df.head(5)
# Out:
#         date  average price  total volume     4046       4225    4770  \
# 0 2015-12-27           1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20           1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13           0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06           1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29           1.28      51039.60   941.48   43838.39   75.78
#
#    total bags  small bags  large bags  xlarge bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
#  here above as we can see in our dataset 'type' & 'region'is of 'object data type'

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# average price           float64
# total volume            float64
# 4046                    float64
# 4225                    float64
# 4770                    float64
# total bags              float64
# small bags              float64
# large bags              float64
# xlarge bags             float64
# type                     object
# year                      int64
# region                   object
# dtype: object

# %%
#  so we need to encode them before aplly any other methods.
#  so first we need to apply ENCODING TECHNIQUE.

# %% [markdown]
# ENCODING TECHNIQUES ========================================================================================================

# %%
# here in our dataset we are having two 'object' columns which need's to be ENCODED for further analysis.
# so here we are apllying "LABEL ENCODER" for both columns:-
#  for which we have to import some libraries

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.head(1)
# Out:
#         date  average price  total volume     4046      4225   4770  \
# 0 2015-12-27           1.33      64236.62  1036.74  54454.85  48.16
#
#    total bags  small bags  large bags  xlarge bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany

# %%
df["type"] = le.fit_transform(df["type"])
df["region"] = le.fit_transform(df["region"])

# %%
df.head(1)
# Out:
#         date  average price  total volume     4046      4225   4770  \
# 0 2015-12-27           1.33      64236.62  1036.74  54454.85  48.16
#
#    total bags  small bags  large bags  xlarge bags  type  year  region
# 0     8696.87     8603.62       93.25          0.0     0  2015       0

# %%
# here above as we can see our type and region column hasbeen succeffuly converted.

# %%
df.dtypes
# as we can see both of the column types are converted from 'object' to 'integer'
# Out:
# date             datetime64[ns]
# average price           float64
# total volume            float64
# 4046                    float64
# 4225                    float64
# 4770                    float64
# total bags              float64
# small bags              float64
# large bags              float64
# xlarge bags             float64
# type                      int32
# year                      int64
# region                    int32
# dtype: object

# %% [markdown]
# ============ FINDING CORRELATION IN DATASET ========================

# %%
cor = df.corr()
cor

# non graphically finding correlation, here we can see that it is difficult to understand this kind of correlation....
# ....so further we find the correlation graphically by HEAT MAP.
# Out:
#                average price  total volume      4046      4225      4770  \
# average price       1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# total volume       -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046               -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225               -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770               -0.179446      0.872202  0.833389  0.887855  1.000000
# total bags         -0.177088      0.963047  0.920057  0.905787  0.792314
# small bags         -0.174730      0.967238  0.925280  0.916031  0.802733
# large bags         -0.172940      0.880640  0.838645  0.810015  0.698471
# xlarge bags        -0.117592      0.747157  0.699377  0.688809  0.679861
# type                0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year                0.093197      0.017193  0.003353 -0.009559 -0.036531
# region             -0.011716      0.174176  0.192073  0.145726  0.095252
#
#                total bags  small bags  large bags  xlarge bags      type  \
# average price   -0.177088   -0.174730   -0.172940    -0.117592  0.615845
# total volume     0.963047    0.967238    0.880640     0.747157 -0.232434
# 4046             0.920057    0.925280    0.838645     0.699377 -0.225819
# 4225             0.905787    0.916031    0.810015     0.688809 -0.232289
# 4770             0.792314    0.802733    0.698471     0.679861 -0.210027
# total bags       1.000000    0.994335    0.943009     0.804233 -0.217788
# small bags       0.994335    1.000000    0.902589     0.806845 -0.220535
# large bags       0.943009    0.902589    1.000000     0.710858 -0.193177
# xlarge bags      0.804233    0.806845    0.710858     1.000000 -0.175483
# type            -0.217788   -0.220535   -0.193177    -0.175483  1.000000
# year             0.071552    0.063915    0.087891     0.081033 -0.000032
# region           0.175256    0.164702    0.198768     0.082281 -0.000280
#
#                    year    region
# average price  0.093197 -0.011716
# total volume   0.017193  0.174176
# 4046           0.003353  0.192073
# 4225          -0.009559  0.145726
# 4770          -0.036531  0.095252
# total bags     0.071552  0.175256
# small bags     0.063915  0.164702
# large bags     0.087891  0.198768
# xlarge bags    0.081033  0.082281
# type          -0.000032 -0.000280
# year           1.000000 -0.000055
# region        -0.000055  1.000000

# %%
plt.figure (figsize = (10,5), facecolor = "white")
sns.heatmap(df.corr(),linewidth=0.1,fmt="0.1g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()


#  Here in the following heat map , we can clearly see the correlation.
# here the columns- 'total volume' is highly correlated with '4046'
#                   'total bags' is higly correlated with 'small bags'
#                    'small bag' & large bags are also highly correlated with each other.

# %% [markdown]
# SITUATION-1 (where target column is  AVERAGE PRICE) ============

# %%
cor['average price'].sort_values(ascending=False)

#  here we can see with 'average price' the highest correlated column is - 'type'
# Out:
# average price    1.000000
# type             0.615845
# year             0.093197
# region          -0.011716
# xlarge bags     -0.117592
# 4225            -0.172928
# large bags      -0.172940
# small bags      -0.174730
# total bags      -0.177088
# 4770            -0.179446
# total volume    -0.192752
# 4046            -0.208317
# Name: average price, dtype: float64

# %% [markdown]
# SITUATION - 2 (where target column is  REGION)================

# %%
cor['region'].sort_values(ascending=False)
# here with the 'region column the HIGHEST CORRELATED COLUMN IS 'LARGE BAGS' & 4046
# Out:
# region           1.000000
# large bags       0.198768
# 4046             0.192073
# total bags       0.175256
# total volume     0.174176
# small bags       0.164702
# 4225             0.145726
# 4770             0.095252
# xlarge bags      0.082281
# year            -0.000055
# type            -0.000280
# average price   -0.011716
# Name: region, dtype: float64

# %% [markdown]
# CHECKING FOR OUTLIERS ======================================================================================================

# %%
df.describe()
# here in the describe methode we are getting soo many STATISTICAL INFORMATION about the dataset for each column.
# 1. first of all above we are getting 'count' for each of the column.
#                 as we know the total number of row counts for each column is 18,249. and here we are getting count for each..
#                 ... column is smame. not a single blank/'nan' is present in any of the column.

# 2. MEAN : In this, we can get MEAN VALUE for the every column.
# 3. STD : which is Standard Deviation , which shows that how the data of the column is deviate from its MEAN.
# 4. MIN : It shows the Minimum value present in the column.
# 5. 25% : It gives us the 25th Percentile Value in the column.
# 6. 50% : It gives us the 50th Percentile Value in the column.
# 7. 75% : It gives us the 75th Percentile Value in the column.
# 8. Max : It gives us the MAXIMUM VALUE present the column.

# As If in any column the Difference between the value at 75th Percentile & MAX is Higher then, there may be presence of outlier
# so we have to check the 75th% & MAX for each of the column.
#  here we find that in the following columns there is huge difference betweeen 75% & MAX :
#  1)- 4771, 2)- small bags, 3)-large bags, 4)- xlarge bags   
# so in the above mentioned columns there may be presence of outliers, but we have to check all of the columns.
# Out:
#        average price  total volume          4046          4225          4770  \
# count   18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean        1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std         0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min         0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%         1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%         1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%         1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max         3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          total bags    small bags    large bags    xlarge bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507      0.499918
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.500014
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000      0.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000      0.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000      0.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000      1.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000      1.000000
#
#                year        region
# count  18249.000000  18249.000000
# mean    2016.147899     26.495644
# std        0.939938     15.583788
# min     2015.000000      0.000000
# 25%     2015.000000     13.000000
# 50%     2016.000000     26.000000
# 75%     2017.000000     40.000000
# max     2018.000000     53.000000

# %%
# By using BOXPLOT METHOD we can chek PRESENCE OF OUTLIERS  in every column.

# %%
df.columns
# Out:
# Index(['date', 'average price', 'total volume', '4046', '4225', '4770',
#        'total bags', 'small bags', 'large bags', 'xlarge bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df1 = df[['average price', 'total volume', '4046', '4225', '4770',
       'total bags', 'small bags', 'large bags', 'xlarge bags', 'type', 'year',
       'region']]
# here we are leaving 'date column' because boxplot allows only numeric column. and date column is in the 'datetime formate'
# therefore for just checking outliers we are making new dataframe 'df1' and apllying boxplot on it.

# %%
df.columns.nunique()
# there are 13 no. of unique columns are present in the dataset.
#  by using forloop we can chek outliers for each column in a single code.
# Out:
# 13

# %%
for i in df1.columns[0:13]:
    plt.figure (figsize = (12,1), facecolor = "white")
    sns.boxplot(x=i,data=df1)
    plt.show()
    
#  here below we can find the outliers for all the cloumns by using boxplot.
#  and we are found outliers in :
#  average price, total volume, 4046, 4225, 4770, total bag, small bags, large bage, x-large bags, are having outliers.
# so out of 13 columns we found OUTLIERS IN 9 COLUMNS , now we have to remove those outliers from out dataset.

# %%
# As we given a situation in which we have to performe operations in 2 ways :
#  1st) we have 'Region' as our Target Column.
#  2nd) we have to take 'Average price' as a our Target Column.

#  we are making two different new datasets df_new1 & df_new2 in thoose datasets we will perform difeerent operations..
# ...in df_new1 we will take 'Region' as our TARGET VARIABLE ['CONDITION-1']
# ...in df_new2 we will take 'Average Price' as our TARGET VARIABLE.['CONDITION-2']

# %% [markdown]
# CONDITION-1 ============== (Target column = Region)

# %%
df_new_01 = df[['average price', 'total volume', '4046', '4225', '4770',
       'total bags', 'small bags', 'large bags', 'xlarge bags', 'type', 'year','region']]

# here in df_new1 dataset, we are taking 'region' also which is our TARGET COLUMN, because here 'region' is our TARGET COLUMN..
# ... but we don't need to perform the following operation on our TARGET COLUMN.

# %%
df_new_01.head(2)
# Out:
#    average price  total volume     4046      4225   4770  total bags  \
# 0           1.33      64236.62  1036.74  54454.85  48.16     8696.87
# 1           1.35      54876.98   674.28  44638.81  58.33     9505.56
#
#    small bags  large bags  xlarge bags  type  year  region
# 0     8603.62       93.25          0.0     0  2015       0
# 1     9408.07       97.49          0.0     0  2015       0

# %%
df_new_01.shape
# Out:
# (18249, 12)

# %%
for i in df_new_01.columns[0:12]:
    plt.figure (figsize = (12,1), facecolor = "skyblue")
    sns.boxplot(x=i,data=df_new_01)
    plt.show()
    
#  here below we can find the outliers for all the cloumns by using boxplot.
#  and we are found outliers in :
#  average price, total volume, 4046, 4225, 4770, total bag, small bags, large bage, x-large bags, are having outliers.
# so out of 13 columns we found OUTLIERS IN 9 COLUMNS , now we have to remove those outliers from out dataset.

# %%
# here in CONDITION 1, we are having 'REGION' as our TARGET COLUMN. so we can't REMOVE OUTLERS from our TARGET COLUMN.

# %% [markdown]
# ========== REMOVING OF OUTLIERS BY USING Z-SCORE METHOD (for condition-1) ====================

# %%
#  we can not remove outliers from out TARGET COLUMN, so first we have to seprate target column first.
# For this first we need to identify the ZSCORE VALUES, for which we have to import some libraries.

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(df_new_01))
z.head(5)

# by applying 'abs' (absolute method), we are getting all the entries whose z-score value is positive side
#  Ideally we can call the OUTLIERS whos ZSCORE VALUE is LESS THEN 3 AND MORE THEN 3
# so we have to remove all the data whose ZSCORE >3 & <3
#  below here we apllying "abs" i.e absolute method it returns us the all zscore values greater then 3
#  so we just need to remove lesserr then 3 zscore values.
# Out:
#    average price  total volume      4046      4225      4770  total bags  \
# 0       0.188689      0.227716  0.230816  0.199902  0.212091    0.234170
# 1       0.139020      0.230427  0.231103  0.208054  0.211997    0.233350
# 2       1.182069      0.212085  0.231007  0.154478  0.211325    0.234730
# 3       0.809551      0.223444  0.230741  0.185350  0.211864    0.237096
# 4       0.312861      0.231538  0.230891  0.208719  0.211834    0.236718
#
#    small bags  large bags  xlarge bags      type      year    region
# 0    0.232647    0.222352      0.17558  0.999836  1.221282  1.700252
# 1    0.231568    0.222335      0.17558  0.999836  1.221282  1.700252
# 2    0.233399    0.222311      0.17558  0.999836  1.221282  1.700252
# 3    0.236568    0.222186      0.17558  0.999836  1.221282  1.700252
# 4    0.236154    0.221924      0.17558  0.999836  1.221282  1.700252

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
# here above we found only 598 outliers,  whose z-score is more then > 3 
# i.e means we are having 598 outlier still present in our dataset, and we have to remove those outliers

# %%
df_condition_01 = df_new_01[(z<3).all(axis=1)]
df_condition_01

# here we can see the difference clearly that, earlier there was 18,249 total rows are there, and now after removing outliers..
# ...there are only 17,651 rows are present in our dataset.
# so there are  598 OUTLIERS are removed during this process.
# Out:
#        average price  total volume     4046       4225    4770  total bags  \
# 0               1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1               1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2               0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3               1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4               1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...              ...           ...      ...        ...     ...         ...
# 18244           1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245           1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246           1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247           1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248           1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        small bags  large bags  xlarge bags  type  year  region
# 0         8603.62       93.25          0.0     0  2015       0
# 1         9408.07       97.49          0.0     0  2015       0
# 2         8042.21      103.14          0.0     0  2015       0
# 3         5677.40      133.76          0.0     0  2015       0
# 4         5986.26      197.69          0.0     0  2015       0
# ...           ...         ...          ...   ...   ...     ...
# 18244    13066.82      431.85          0.0     1  2018      53
# 18245     8940.04      324.80          0.0     1  2018      53
# 18246     9351.80       42.31          0.0     1  2018      53
# 18247    10919.54       50.00          0.0     1  2018      53
# 18248    11988.14       26.01          0.0     1  2018      53
#
# [17651 rows x 12 columns]

# %%
df_condition_01.shape
# Out:
# (17651, 12)

# %%
df_new_01.shape
# Out:
# (18249, 12)

# %%
#  here above we can clearly see the difference, 598 outliers are removed from the new dataset.

# %% [markdown]
# ===============CHECKING REMOVAL OF OUTLIERS BY BOXPLOT (COMPARING  'df_new_01'  &  'df_condition_01') ========================

# %%
df_condition_01.columns
# Out:
# Index(['average price', 'total volume', '4046', '4225', '4770', 'total bags',
#        'small bags', 'large bags', 'xlarge bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
df_condition_01.columns.nunique()
# Out:
# 12

# %%
# now in the earlier findings we found that there are may presence of outliers in some of the columns....
# ....i.e (average price, total volume, 4046, 4225, 4770, total bag, small bags, large bage, x-large bags, are having outliers.)
#  now we have to check out of these columns which outlier hasbeen removed from the dataset.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='average price',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='average price',data=df_condition_01, color='m')
plt.xlabel('\nAverage Price \n\n 1')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from 'AVERAGE PRICE' column.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='total volume',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='total volume',data=df_condition_01, color='m')
plt.xlabel('Total Volume \n\n 2')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from 'TOTAL VOLUME' column.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='4046',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='4046',data=df_condition_01, color='m')
plt.xlabel('AVOCADO-4046 \n\n 3')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from '4046' column.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='4225',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='4225',data=df_condition_01, color='m')
plt.xlabel('AVOCADO-4225 \n\n 4')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from '4225' column.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='4770',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='4770',data=df_condition_01, color='m')
plt.xlabel('AVOCADO-4770 \n\n 5')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from '4770' column.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='total bags',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='total bags',data=df_condition_01, color='m')
plt.xlabel('Total Bags \n\n 6')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from 'TOTAL BAGS' column.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='small bags',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='small bags',data=df_condition_01, color='m')
plt.xlabel('Small Bags \n\n 7')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from 'SMALL BAGS' column.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='large bags',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='large bags',data=df_condition_01, color='m')
plt.xlabel('Large Bags \n\n 8')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from 'LARGE BAGS' column.

# %%
plt.figure (figsize = (12,1), facecolor = "skyblue")
# sns.set(style="darkgrid")
sns.boxplot(x='xlarge bags',data=df_new_01)
plt.show()

# it is the EARLIER (df_new1 dataset) PRESENCE OF OUTLIERS

plt.figure (figsize = (12,1), facecolor = "skyblue")
sns.boxplot(x='xlarge bags',data=df_condition_01, color='m')
plt.xlabel('Xtra Large Bags \n\n 9')
plt.show()

# outliers are succesfully removed.
# it is the Newer (df_condition1 dataset)  OUTLIERS ARE REMOVED.
# So as we can see , outlier which is removed above by Z-SCORE METHOD is from 'X-LARGE BAGS' column.

# %%
#  here above we have sucessfully removed OutLiers from the Mentioned 9 Columns

# %%
df_condition_01.shape

# TARGET COLUMN IS 'REGION'
# Out:
# (17651, 12)

# %% [markdown]
# ================================== FINDING & REMOVAL OF OUTLIERS ARE COMPLETED =======================================

# %% [markdown]
# CHECKING SKEWNESS  ======================================================

# %%
# the skewness shows the distribution of data, if the data is widely skewed that means it is not good for our model.
#  ideal range of skewness is ( -0.5 to +0.5)
# We can't remove skewness from our Target Column

# %% [markdown]
# FOR SITUATION -1 =========>>>>>

# %%
df_condition_01.skew()

# here below w find that highesht skewd columns are - 'total volume''total bags' 'xlarge/large/small bags', '4770''4225''4046'
# first fo all we have to remove skewness form the 'xlarge bags' & other colunm, then we can chek again...
# Out:
# average price    0.377432
# total volume     3.767138
# 4046             4.909848
# 4225             4.455745
# 4770             5.117170
# total bags       4.066771
# small bags       4.222706
# large bags       5.053434
# xlarge bags      6.135607
# type            -0.037741
# year             0.229976
# region           0.012798
# dtype: float64

# %%
# the skewness shows the distribution of data, if the data is widely skewed that means it is not good for our model.
#  ideal range of skewness is ( -0.5 to +0.5)
# We can't remove skewness from our Target Column
# here we can see the skewness is present in 'total volume''total bags' 'xlarge/large/small bags', '4770''4225''4046'
#  so we need to remove skewness from those mentioned columns.

# %%
# so we have to remove skewness from those columns by using 'cuberoot' method.

# %%
df_condition_01['xlarge bags'] = np.cbrt(df_condition_01['xlarge bags'])

# %%
df_condition_01['large bags'] = np.cbrt(df_condition_01['large bags'])

# %%
df_condition_01['small bags'] = np.cbrt(df_condition_01['small bags'])

# %%
df_condition_01['4770'] = np.cbrt(df_condition_01['4770'])

# %%
df_condition_01['4225'] = np.cbrt(df_condition_01['4225'])

# %%
df_condition_01['4046'] = np.cbrt(df_condition_01['4046'])

# %%
df_condition_01['total volume'] = np.cbrt(df_condition_01['total volume'])

# %%
df_condition_01['total bags'] = np.cbrt(df_condition_01['total bags'])

# %%
df_condition_01.skew()
# here in the following we can see that the skewness not in the ideal condition but it is much controlled compared to earlier.
# Out:
# average price    0.377432
# total volume     1.240435
# 4046             1.555876
# 4225             1.277025
# 4770             1.635614
# total bags       1.231831
# small bags       1.246033
# large bags       1.276213
# xlarge bags      2.277028
# type            -0.037741
# year             0.229976
# region           0.012798
# dtype: float64

# %%
#  here above we can see that the skewness for both of the situations is reduced.

# %% [markdown]
# ======================== REMOVED SKEWNESS SUCCESSFULLY ================================

# %% [markdown]
# DIVIDING DATA INTO INDEPENDENT & TARGET VARIABLE ===================================================================================================================

# %%
#  CONDITION-1  (Where Target Column is =  'REGION' )

# %%
df_condition_01.shape
# Out:
# (17651, 12)

# %%
df_condition_01.columns
# Out:
# Index(['average price', 'total volume', '4046', '4225', '4770', 'total bags',
#        'small bags', 'large bags', 'xlarge bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
# here we are giving with two situations :
#  1) SITUATION 1 = where Target column is = 'Average Price'
#  2) SITUATION 2 = where target column is = 'region'

# so we are going to make 2 different datasets for SITUATION 1 & 2 , with the name of x1-y1, & x2-y2
#  in x1-y1 ( target column is - AVERAGE PRICE)
#  in x2-y2 ( target column is - REGION)

# %% [markdown]
# SITUATION-1 ===  (where target column is - AVERAGE PRICE )

# %%
x1 = df_condition_01[['total volume', '4046', '4225', '4770', 'total bags',
       'small bags', 'large bags', 'xlarge bags', 'type', 'year', 'region']]

# %%
y1 = df_condition_01[['average price']]

# %%
x1.head(2)
# Out:
#    total volume       4046       4225      4770  total bags  small bags  \
# 0     40.049235  10.120997  37.903460  3.638275   20.564634   20.490870
# 1     38.001150   8.768933  35.473513  3.878204   21.183249   21.110581
#
#    large bags  xlarge bags  type  year  region
# 0    4.534711          0.0     0  2015       0
# 1    4.602425          0.0     0  2015       0

# %%
y1.head(2)
# Out:
#    average price
# 0           1.33
# 1           1.35

# %%
x1.shape
# Out:
# (17651, 11)

# %%
y1.shape
# Out:
# (17651, 1)

# %% [markdown]
# SITUATION -2  ========     (where target column is = REGION)

# %%
df_condition_01.shape
# Out:
# (17651, 12)

# %%
df_condition_01.columns
# Out:
# Index(['average price', 'total volume', '4046', '4225', '4770', 'total bags',
#        'small bags', 'large bags', 'xlarge bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
x2 = df_condition_01[['average price', 'total volume', '4046', '4225', '4770', 'total bags',
       'small bags', 'large bags', 'xlarge bags', 'type', 'year']]

# %%
y2 = df_condition_01[['region']]

# %%
x2.head(2)
# Out:
#    average price  total volume       4046       4225      4770  total bags  \
# 0           1.33     40.049235  10.120997  37.903460  3.638275   20.564634
# 1           1.35     38.001150   8.768933  35.473513  3.878204   21.183249
#
#    small bags  large bags  xlarge bags  type  year
# 0   20.490870    4.534711          0.0     0  2015
# 1   21.110581    4.602425          0.0     0  2015

# %%
y2.head(2)
# Out:
#    region
# 0       0
# 1       0

# %%
x2.shape
# Out:
# (17651, 11)

# %%
y2.shape
# Out:
# (17651, 1)

# %%
# here above we seprates independent and dependent columns successfully.

# %% [markdown]
#  APPLYING SCALING TECHNIQUES ==================================================================================================================>>>>>>

# %%
# here we need to apply scaling techniques on our dataset,by scaling techniques we normalise the values.
#  we can't apply SCALING TECHNIQUES on TARGET VARIABLE
#  to aplly scaling techinuque we need to import some libraries first.

# %%
from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()

# %% [markdown]
# SITUATION-1 ====== (where target column is 'AVERAGE PRICE') =========================

# %%
x1 = st.fit_transform(x1)
x1
# Out:
# array([[-0.36001678, -0.7096478 ,  0.05964226, ..., -1.01904715,
#         -1.21001338, -1.69549505],
#        [-0.41358063, -0.75506378, -0.0254953 , ..., -1.01904715,
#         -1.21001338, -1.69549505],
#        [-0.12385558, -0.73848038,  0.40604959, ..., -1.01904715,
#         -1.21001338, -1.69549505],
#        ...,
#        [-0.78062205, -0.69346796, -0.79586353, ...,  0.98130886,
#          1.98075592,  1.74705401],
#        [-0.74560645, -0.66275586, -0.76412245, ...,  0.98130886,
#          1.98075592,  1.74705401],
#        [-0.72856457, -0.57089182, -0.80215382, ...,  0.98130886,
#          1.98075592,  1.74705401]])

# %%
xf1 = pd.DataFrame(data=x1)
print(xf1)

# here we get our dataset (xf1) after applying SCALING TECHING (STANDARD SCALER)
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.360017 -0.709648  0.059642 -0.533970 -0.648548 -0.517773 -0.796802
# 1     -0.413581 -0.755064 -0.025495 -0.516157 -0.623078 -0.490834 -0.792817
# 2     -0.123856 -0.738480  0.406050 -0.427502 -0.666838 -0.537584 -0.787683
# 3     -0.285278 -0.699539  0.189057 -0.494395 -0.755024 -0.633026 -0.762704
# 4     -0.437308 -0.720397 -0.032969 -0.489909 -0.739523 -0.619211 -0.720851
# ...         ...       ...       ...       ...       ...       ...       ...
# 17646 -0.733974 -0.623118 -0.864717 -0.804096 -0.514919 -0.384638 -0.618863
# 17647 -0.778787 -0.693490 -0.739905 -0.804096 -0.630504 -0.506311 -0.659154
# 17648 -0.780622 -0.693468 -0.795864 -0.136211 -0.626500 -0.492667 -0.858596
# 17649 -0.745606 -0.662756 -0.764122 -0.136496 -0.580423 -0.444110 -0.846859
# 17650 -0.728565 -0.570892 -0.802154 -0.352835 -0.552260 -0.413625 -0.889294
#
#             7         8         9         10
# 0     -0.51836 -1.019047 -1.210013 -1.695495
# 1     -0.51836 -1.019047 -1.210013 -1.695495
# 2     -0.51836 -1.019047 -1.210013 -1.695495
# 3     -0.51836 -1.019047 -1.210013 -1.695495
# 4     -0.51836 -1.019047 -1.210013 -1.695495
# ...        ...       ...       ...       ...
# 17646 -0.51836  0.981309  1.980756  1.747054
# 17647 -0.51836  0.981309  1.980756  1.747054
# 17648 -0.51836  0.981309  1.980756  1.747054
# 17649 -0.51836  0.981309  1.980756  1.747054
# 17650 -0.51836  0.981309  1.980756  1.747054
#
# [17651 rows x 11 columns]

# %%
xf1.columns
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
df_condition_01.columns
# Out:
# Index(['average price', 'total volume', '4046', '4225', '4770', 'total bags',
#        'small bags', 'large bags', 'xlarge bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
column1 = ['total volume', '4046', '4225', '4770', 'total bags',
       'small bags', 'large bags', 'xlarge bags', 'type', 'year', 'region']

# %%
xf1.columns = column1

# %%
xf1.head(2)
# Out:
#    total volume      4046      4225      4770  total bags  small bags  \
# 0     -0.360017 -0.709648  0.059642 -0.533970   -0.648548   -0.517773
# 1     -0.413581 -0.755064 -0.025495 -0.516157   -0.623078   -0.490834
#
#    large bags  xlarge bags      type      year    region
# 0   -0.796802     -0.51836 -1.019047 -1.210013 -1.695495
# 1   -0.792817     -0.51836 -1.019047 -1.210013 -1.695495

# %%
yf1 = y1

# %%
yf1.head(2)
# Out:
#    average price
# 0           1.33
# 1           1.35

# %% [markdown]
# SITUATION-2 ====     (where target column is  REGION)=========================

# %%
x2 = st.fit_transform(x2)
x2
# Out:
# array([[-0.19535234, -0.36001678, -0.7096478 , ..., -0.51835993,
#         -1.01904715, -1.21001338],
#        [-0.1435096 , -0.41358063, -0.75506378, ..., -0.51835993,
#         -1.01904715, -1.21001338],
#        [-1.2322071 , -0.12385558, -0.73848038, ..., -0.51835993,
#         -1.01904715, -1.21001338],
#        ...,
#        [ 1.20440158, -0.78062205, -0.69346796, ..., -0.51835993,
#          0.98130886,  1.98075592],
#        [ 1.35992979, -0.74560645, -0.66275586, ..., -0.51835993,
#          0.98130886,  1.98075592],
#        [ 0.55636736, -0.72856457, -0.57089182, ..., -0.51835993,
#          0.98130886,  1.98075592]])

# %%
xf2 = pd.DataFrame(data=x2)
print(xf2)

# here we get our dataset (xf2) after applying SCALING TECHING (STANDARD SCALER)
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.195352 -0.360017 -0.709648  0.059642 -0.533970 -0.648548 -0.517773
# 1     -0.143510 -0.413581 -0.755064 -0.025495 -0.516157 -0.623078 -0.490834
# 2     -1.232207 -0.123856 -0.738480  0.406050 -0.427502 -0.666838 -0.537584
# 3     -0.843387 -0.285278 -0.699539  0.189057 -0.494395 -0.755024 -0.633026
# 4     -0.324959 -0.437308 -0.720397 -0.032969 -0.489909 -0.739523 -0.619211
# ...         ...       ...       ...       ...       ...       ...       ...
# 17646  0.582289 -0.733974 -0.623118 -0.864717 -0.804096 -0.514919 -0.384638
# 17647  0.789660 -0.778787 -0.693490 -0.739905 -0.804096 -0.630504 -0.506311
# 17648  1.204402 -0.780622 -0.693468 -0.795864 -0.136211 -0.626500 -0.492667
# 17649  1.359930 -0.745606 -0.662756 -0.764122 -0.136496 -0.580423 -0.444110
# 17650  0.556367 -0.728565 -0.570892 -0.802154 -0.352835 -0.552260 -0.413625
#
#              7        8         9         10
# 0     -0.796802 -0.51836 -1.019047 -1.210013
# 1     -0.792817 -0.51836 -1.019047 -1.210013
# 2     -0.787683 -0.51836 -1.019047 -1.210013
# 3     -0.762704 -0.51836 -1.019047 -1.210013
# 4     -0.720851 -0.51836 -1.019047 -1.210013
# ...         ...      ...       ...       ...
# 17646 -0.618863 -0.51836  0.981309  1.980756
# 17647 -0.659154 -0.51836  0.981309  1.980756
# 17648 -0.858596 -0.51836  0.981309  1.980756
# 17649 -0.846859 -0.51836  0.981309  1.980756
# 17650 -0.889294 -0.51836  0.981309  1.980756
#
# [17651 rows x 11 columns]

# %%
xf2.columns
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
df_condition_01.columns
# Out:
# Index(['average price', 'total volume', '4046', '4225', '4770', 'total bags',
#        'small bags', 'large bags', 'xlarge bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
column2 = ['average price', 'total volume', '4046', '4225', '4770', 'total bags',
       'small bags', 'large bags', 'xlarge bags', 'type', 'year']

# %%
xf2.columns = column2

# %%
xf2.head(2)
# Out:
#    average price  total volume      4046      4225      4770  total bags  \
# 0      -0.195352     -0.360017 -0.709648  0.059642 -0.533970   -0.648548
# 1      -0.143510     -0.413581 -0.755064 -0.025495 -0.516157   -0.623078
#
#    small bags  large bags  xlarge bags      type      year
# 0   -0.517773   -0.796802     -0.51836 -1.019047 -1.210013
# 1   -0.490834   -0.792817     -0.51836 -1.019047 -1.210013

# %%
yf2 = y2

# %%
yf2.head(2)
# Out:
#    region
# 0       0
# 1       0

# %% [markdown]
# FINDING MULTICOLINEARITY ======================================================================================================================

# %%
# We have to find the multicollinearity between the features and to remove it we can use VIF (VARIANCE INFLATION FACTOR)
# we can not apply VIF on the TARGET COLUMN
# for apllyin VIF we have to import some libraries as follows

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels .stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# FINDING MULTICOLINEARITY IN SITUATION-1 ================= (where 'AVERAGE PRICE' is target column==============

# %%
# here we are making "def function" for calculating VIF
def calc_vif(xf1):
    vif = pd.DataFrame()
    vif["FETURES"] = xf1.columns
    vif["VIF FACTOR"] = [variance_inflation_factor(xf1.values,i) for i in range (xf1.shape[1])]
    return (vif)

# %%
xf1.shape
# Out:
# (17651, 11)

# %%
yf1.shape
# Out:
# (17651, 1)

# %%
calc_vif(xf1)
# here we find that VIF VALUE of 'TOTAL VOLUME ' & TOTAL BAGS is very high.
#  they are Highly MULTICOLLINERED COLUMNS. we have to drop one of the column between them.
#
# Out:
#          FETURES  VIF FACTOR
# 0   total volume  202.503330
# 1           4046   24.866826
# 2           4225   40.464243
# 3           4770    3.301017
# 4     total bags  117.508648
# 5     small bags   63.622958
# 6     large bags    9.031383
# 7    xlarge bags    1.968262
# 8           type    2.182953
# 9           year    1.317551
# 10        region    1.114124

# %%
cor['average price'].sort_values(ascending=False)
# here we can see that the 'total volume column ' & 'total bags' are not much correlated with the target column = AVERAGE PRICE
# So we can drop 'total volume' & 'total bags' column
# Out:
# average price    1.000000
# type             0.615845
# year             0.093197
# region          -0.011716
# xlarge bags     -0.117592
# 4225            -0.172928
# large bags      -0.172940
# small bags      -0.174730
# total bags      -0.177088
# 4770            -0.179446
# total volume    -0.192752
# 4046            -0.208317
# Name: average price, dtype: float64

# %%
xf1.drop(['total volume'],axis=1,inplace=True)

# %%
xf1.drop(['total bags'],axis=1,inplace=True)

# %%
calc_vif(xf1)
# here now multicolinearity is very much reduced as compared to earlier
# Out:
#        FETURES  VIF FACTOR
# 0         4046    4.143428
# 1         4225    5.477961
# 2         4770    3.269070
# 3   small bags    6.541084
# 4   large bags    2.116928
# 5  xlarge bags    1.934397
# 6         type    2.166444
# 7         year    1.311936
# 8       region    1.089408

# %% [markdown]
# FINDING MULTICOLINEARITY IN SITUATION-2 ================= (where 'REGION' is target column)================

# %%
# here we are making "def function" for calculating VIF
def calc_vif(xf2):
    vif = pd.DataFrame()
    vif["FETURES"] = xf2.columns
    vif["VIF FACTOR"] = [variance_inflation_factor(xf2.values,i) for i in range (xf2.shape[1])]
    return (vif)

# %%
calc_vif(xf2)
# here we find that VIF VALUE of 'TOTAL VOLUME ' & TOTAL BAGS is very high.
#  they are Highly MULTICOLLINERED COLUMNS. we have to drop one of the column between them.
# Out:
#           FETURES  VIF FACTOR
# 0   average price    2.018698
# 1    total volume  203.647267
# 2            4046   23.961766
# 3            4225   42.078549
# 4            4770    3.284587
# 5      total bags  120.152468
# 6      small bags   66.701023
# 7      large bags    9.113256
# 8     xlarge bags    1.975705
# 9            type    2.696459
# 10           year    1.352954

# %%
cor['region'].sort_values(ascending=False)
# here we can see that the 'total volume column ' & 'total bags' are not much correlated with the target column = REGION
# So we can drop 'total volume' & 'total bags' column
# Out:
# region           1.000000
# large bags       0.198768
# 4046             0.192073
# total bags       0.175256
# total volume     0.174176
# small bags       0.164702
# 4225             0.145726
# 4770             0.095252
# xlarge bags      0.082281
# year            -0.000055
# type            -0.000280
# average price   -0.011716
# Name: region, dtype: float64

# %%
xf2.drop(['total volume'],axis=1,inplace=True)
xf2.drop(['total bags'],axis=1,inplace=True)

# %%
calc_vif(xf2)
# now here we did't find any higher multicolinearity .
# Out:
#          FETURES  VIF FACTOR
# 0  average price    1.856196
# 1           4046    4.063847
# 2           4225    5.648659
# 3           4770    3.249044
# 4     small bags    6.545230
# 5     large bags    2.215059
# 6    xlarge bags    1.938176
# 7           type    2.671380
# 8           year    1.339645

# %%
xf1.shape
# Out:
# (17651, 9)

# %%
yf1.shape
# Out:
# (17651, 1)

# %%
#  xf1 & yf1 is dataset where the target column is - AVERAGE PRICE

# %%
xf2.shape
# Out:
# (17651, 9)

# %%
yf2.shape
# Out:
# (17651, 1)

# %%
#  xf2 & yf2 is dataset where the target column is - REGION

# %% [markdown]
# =========== Upto here EDA & OTHER TECHNIQUES are completed for both of SITUATION-1 & SITUATION-2 ===================

# %% [markdown]
# ============ NOW WE NEED TO APPLY ML-MODELS FOR BOTH OF THE SITUATIONS =============================

# %%
# Here in the given dataset we are provided with the 2 SITUATION, where...
#  in SITUATION-1 = We have to Predict 'AVERAGE PRICE' for AVOCADO, which is in DECIMAL FORM.
#                   so for situation-1 we have to aplly REGRESSION MODEL.

#  in SITUATION-2 = We have to predict the 'REGION' for the AVOCADO, which is a CATEGORICAL & OBJECT DATATYPE
#                   therefore for situation-2 we have to aplly CLASSIFICATION MODEL.

# the CONCLUSION IS THAT WE ARE MAKEING 2 DIFFERENT ML-MODELS, THEREFORE WE WOULD HAVE 2 DIFFERENT (.pkl) files.

# %% [markdown]
# APPLYING MODEL FOR SITUATION-1  (REGRESSION MODEL)  =========================

# %%
xf1.head()
# Out:
#        4046      4225      4770  small bags  large bags  xlarge bags  \
# 0 -0.709648  0.059642 -0.533970   -0.517773   -0.796802     -0.51836
# 1 -0.755064 -0.025495 -0.516157   -0.490834   -0.792817     -0.51836
# 2 -0.738480  0.406050 -0.427502   -0.537584   -0.787683     -0.51836
# 3 -0.699539  0.189057 -0.494395   -0.633026   -0.762704     -0.51836
# 4 -0.720397 -0.032969 -0.489909   -0.619211   -0.720851     -0.51836
#
#        type      year    region
# 0 -1.019047 -1.210013 -1.695495
# 1 -1.019047 -1.210013 -1.695495
# 2 -1.019047 -1.210013 -1.695495
# 3 -1.019047 -1.210013 -1.695495
# 4 -1.019047 -1.210013 -1.695495

# %%
yf1.head()
# Out:
#    average price
# 0           1.33
# 1           1.35
# 2           0.93
# 3           1.08
# 4           1.28

# %%
# NOW HERE WE CAN SEE THAT OUR TARGET/LABEL COLUMN IN NOT A CATEGORICAL DATA, IT IS HAVING NUMERICAL/DECIMAL DATA,
# AND WHEN WE ARE HAVING "Y" (TARGET) IN NUMERICAL/DECIMAL FORM THEN WE CAN APPLY "REGRESSION MODEL", 
# SO HERE WE CAN APPLY REGRESSION MODEL ON OUR DATASET TO PREDICT, "AVERAGE PRICE" for AVOCADO.

# %%
#  LOGISTIC REGRESSION = here we can't aplly this logistic regression, because our target target column is not .....
#                        ...numeric categorical. we can aplly logistic regression where the target column is numeric categorical

#  RIDGE REGRESSION = we can apply ridge regression wher the data is HIGHLY MULTICOLINEARED with each other. here there is .....
#                     ....no such situation like this.

# LINEAR REGRESSION = here we are going to aplly LINEAR REGRESSION MODEL with the above situation.
#           for this we need to import some libraries first.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
lr = LinearRegression()

# %%
yf1.head(1)
# Out:
#    average price
# 0           1.33

# %%
 x_train,x_test,y_train,y_test = train_test_split(xf1,yf1,test_size=0.20,random_state=42)

# %%
lr.fit(x_train,y_train)
print(lr.score(x_train,y_train))
pred_y = lr.predict (x_test)
pred_y
print("mean squared error:", np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# 0.46200710047406046
# mean squared error: 0.28020957259038215

# %%
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
y_test.head(),y_pred[0:5]

# here below we can find 5 actual and 5 predicted values.
# Out:
# (       average price
#  3596            1.36
#  7141            1.70
#  4625            1.22
#  5456            0.81
#  10969           1.85,
#  array([[0.993422  ],
#         [1.40137287],
#         [1.22445309],
#         [1.03190436],
#         [1.58992131]]))

# %%
Accuracy=r2_score(y_test,y_pred)*100
print(" Accuracy of the model is %.2f" %Accuracy)
# Out:
#  Accuracy of the model is 46.85

# %%
mse = mean_squared_error (y_test,y_pred)
mse
# here our MEAN SQURED ERROR is very less, which is a very good indication for the model.
# Out:
# 0.07851740457128466

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.46845561121038504

# %%
print(f'Intercept: {lr.intercept_[0]}')
print(f'Coefficient: {lr.coef_[0][0]}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'R-squared (R2): {r2:.2f}')
# Out:
# Intercept: 1.4075941669671277
# Coefficient: -0.08008733000220762
# Mean Squared Error (MSE): 0.08
# R-squared (R2): 0.47

# %%
# plt.scatter(y_test,y_pred);
# plt.plot(x_test, y_pred, color='red', linewidth=2, label='Regression Line')
# plt.xlabel('Actual');
# plt.ylabel('Predicted');

# %%
print("X shape:", x_test.shape)
print("y shape:", y_test.shape)
# Out:
# X shape: (3531, 9)
# y shape: (3531, 1)

# %%
xf1.shape
# Out:
# (17651, 9)

# %%
def pred_func(ap):
    ap= ap.reshape(1,9)
    average_price = lr.predict(ap)
    print(average_price)
    
# making 'def' function to predict Average Price for Avocado.

# %%
# TEST SAMPLE-1

# %%
ap= np.array([-0.709648,0.059642,-0.533970,-0.517773,-0.796802,-0.51836,-1.019047,-1.210013,-1.695495])
pred_func(ap)

#  data taken from 0th position from 'xf1.head(5)'
# here the ATUAL PRICE FOR GIVEN DATA IS = 1.33
#       & THE PREDICTED PRICE BY MODEL IS = 1.26
# Out:
# [[1.25945713]]

# %%
# TEST SAMPLE-2

# %%
ap= np.array([-0.738480,0.406050,-0.427502,-0.537584,-0.787683,-0.51836,-1.019047,-1.210013,-1.695495])
pred_func(ap)

#  data taken from 2nd position from 'xf1.head(5)'
# here the ATUAL PRICE FOR GIVEN DATA IS = 0.93
#       & THE PREDICTED PRICE BY MODEL IS = 1.30
# Out:
# [[1.30014429]]

# %%
# TEST SAMPLE-3

# %%
ap= np.array([-0.720397,-0.032969,-0.489909,-0.619211,-0.720851,-0.51836,-1.019047,-1.210013,-1.695495])
pred_func(ap)

#  data taken from 4th position from 'xf1.head(5)'
# here the ATUAL PRICE FOR GIVEN DATA IS = 1.28
#       & THE PREDICTED PRICE BY MODEL IS = 1.24
# Out:
# [[1.24458365]]

# %%
xf1.head(5)
# Out:
#        4046      4225      4770  small bags  large bags  xlarge bags  \
# 0 -0.709648  0.059642 -0.533970   -0.517773   -0.796802     -0.51836
# 1 -0.755064 -0.025495 -0.516157   -0.490834   -0.792817     -0.51836
# 2 -0.738480  0.406050 -0.427502   -0.537584   -0.787683     -0.51836
# 3 -0.699539  0.189057 -0.494395   -0.633026   -0.762704     -0.51836
# 4 -0.720397 -0.032969 -0.489909   -0.619211   -0.720851     -0.51836
#
#        type      year    region
# 0 -1.019047 -1.210013 -1.695495
# 1 -1.019047 -1.210013 -1.695495
# 2 -1.019047 -1.210013 -1.695495
# 3 -1.019047 -1.210013 -1.695495
# 4 -1.019047 -1.210013 -1.695495

# %%
yf1.head(5)
# Out:
#    average price
# 0           1.33
# 1           1.35
# 2           0.93
# 3           1.08
# 4           1.28

# %% [markdown]
# SAVING THE MODEL ========================================================================================================

# %%
import pickle

# %%
file_name = 'Avocado Average Price Prediction.pkl' 
pickle.dump(lr,open(file_name,'wb'))

# %% [markdown]
# APPLYING MODEL FOR SITUATION-2  (CLASSIFICATION MODEL)  =========================

# %%
xf2.head()
# Out:
#    average price      4046      4225      4770  small bags  large bags  \
# 0      -0.195352 -0.709648  0.059642 -0.533970   -0.517773   -0.796802
# 1      -0.143510 -0.755064 -0.025495 -0.516157   -0.490834   -0.792817
# 2      -1.232207 -0.738480  0.406050 -0.427502   -0.537584   -0.787683
# 3      -0.843387 -0.699539  0.189057 -0.494395   -0.633026   -0.762704
# 4      -0.324959 -0.720397 -0.032969 -0.489909   -0.619211   -0.720851
#
#    xlarge bags      type      year
# 0     -0.51836 -1.019047 -1.210013
# 1     -0.51836 -1.019047 -1.210013
# 2     -0.51836 -1.019047 -1.210013
# 3     -0.51836 -1.019047 -1.210013
# 4     -0.51836 -1.019047 -1.210013

# %%
yf2.head()
# Out:
#    region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# NOW HERE WE CAN SEE THAT OUR TARGET/LABEL COLUMN ('REGION') IS CATEGORICAL DATA, IT IS HAVING NUMERICAL-CATGEGORICAL DATA,
# AND WHEN WE ARE HAVING "Y" (TARGET) IN NUMERICAL/CATEGORICAL FORM THEN WE CAN APPLY "CLASSIFICATION MODEL", 
# SO HERE WE CAN APPLY CLASSIFICATION MODEL'S ON OUR DATASET TO PREDICT, "REGION" for AVOCADO.

# %%
 x_train,x_test,y_train,y_test = train_test_split(xf2,yf2,test_size=0.20,random_state=42)

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %%
lg = LogisticRegression()
gnb = GaussianNB()
svc = SVC()
dtc = DecisionTreeClassifier()
knn = KNeighborsClassifier()

# %%
ml_model = [lg,gnb,svc,dtc,knn]

# %%
for i in ml_model:
    i.fit(x_train,y_train)
    i.score(x_train,y_train)
    ipred = i.predict(x_train)
    
    print('Accuracy Score of ', i,'is:')
    print (accuracy_score(y_train,ipred))
    
    print(confusion_matrix(y_train,ipred))
    print(classification_report(y_train,ipred))
    print('\n')
# Out:
# Accuracy Score of  LogisticRegression() is:
# 0.5086402266288952
# [[131   0   0 ...   0   0   0]
#  [  0  88   0 ...   0   0   2]
#  [  0   0 183 ...   0   0  21]
#  ...
#  [  0   0   0 ... 124   2   0]
#  [  0   0   0 ...   0 190   0]
#  [  0  14   0 ...   0   0  66]]
#               precision    recall  f1-score   support
#
#            0       0.40      0.49      0.44       270
#            1       0.32      0.33      0.32       268
#            2       0.66      0.67      0.66       274
#            3       0.53      0.46      0.49       267
#            4       0.49      0.52      0.50       269
#            5       0.44      0.53      0.48       266
#            6       0.78      0.85      0.81       234
#            7       0.60      0.70      0.65       254
#            8       0.71      0.81      0.76       284
#            9       0.42      0.69      0.52       262
#           10       0.58      0.32      0.41       279
#           11       0.40      0.52      0.45       270
#           12       0.47      0.51      0.49       270
#           13       0.47      0.38      0.42       274
#           14       0.69      0.47      0.56       264
#           15       0.66      0.75      0.70       212
#           16       0.52      0.46      0.49       263
#           17       0.53      0.75      0.62       272
#           18       0.22      0.15      0.18       259
#           19       0.72      0.45      0.55       268
#           20       0.39      0.61      0.48       260
#           21       0.39      0.33      0.36       274
#           22       0.75      0.67      0.70       259
#           23       0.51      0.79      0.62       279
#           24       0.23      0.21      0.22       270
#           25       0.63      0.65      0.64       256
#           26       0.15      0.10      0.12       275
#           27       0.30      0.64      0.41       270
#           28       0.72      0.73      0.72       277
#           29       0.84      0.87      0.86       267
#           30       0.30      0.21      0.25       261
#           31       0.39      0.31      0.34       275
#           32       0.54      0.52      0.53       276
#           33       0.26      0.25      0.25       257
#           34       0.38      0.24      0.29       278
#           35       0.74      0.53      0.62       276
#           36       0.40      0.23      0.29       282
#           37       0.48      0.56      0.52       275
#           38       0.44      0.45      0.44       270
#           39       0.42      0.60      0.49       273
#           40       0.59      0.94      0.73       267
#           41       0.34      0.28      0.31       260
#           42       0.75      0.72      0.74       236
#           43       0.40      0.23      0.29       267
#           44       0.50      0.24      0.32       257
#           45       0.85      0.89      0.87       226
#           46       0.67      0.69      0.68       247
#           47       0.45      0.37      0.40       248
#           48       0.55      0.32      0.40       266
#           49       0.40      0.71      0.51       273
#           50       0.33      0.15      0.20       267
#           51       0.99      0.95      0.97       130
#           52       0.86      0.87      0.87       218
#           53       0.40      0.25      0.31       269
#
#     accuracy                           0.51     14120
#    macro avg       0.52      0.52      0.51     14120
# weighted avg       0.51      0.51      0.50     14120
#
#
#
# Accuracy Score of  GaussianNB() is:
# 0.21579320113314449
# [[ 74   0   0 ...   0   0   0]
#  [  3  53   0 ...   0   0   9]
#  [ 52   0  90 ...   0   0   0]
#  ...
#  [  0   0   0 ... 130   0   0]
#  [  0  11   0 ...   8  62   0]
#  [ 37   0   0 ...   0   0   2]]
#               precision    recall  f1-score   support
#
#            0       0.08      0.27      0.13       270
#            1       0.15      0.20      0.17       268
#            2       0.47      0.33      0.39       274
#            3       0.18      0.35      0.24       267
#            4       0.43      0.16      0.23       269
#            5       0.32      0.22      0.26       266
#            6       0.91      0.39      0.55       234
#            7       0.33      0.07      0.12       254
#            8       0.79      0.42      0.55       284
#            9       0.38      0.39      0.38       262
#           10       0.22      0.08      0.11       279
#           11       0.30      0.26      0.28       270
#           12       0.25      0.44      0.32       270
#           13       0.26      0.30      0.27       274
#           14       0.65      0.22      0.33       264
#           15       0.79      0.33      0.47       212
#           16       0.25      0.25      0.25       263
#           17       0.15      0.23      0.18       272
#           18       0.24      0.20      0.22       259
#           19       0.34      0.21      0.26       268
#           20       0.10      0.04      0.06       260
#           21       0.05      0.05      0.05       274
#           22       0.39      0.46      0.42       259
#           23       0.08      0.10      0.09       279
#           24       0.60      0.07      0.12       270
#           25       0.44      0.45      0.45       256
#           26       0.17      0.11      0.13       275
#           27       0.33      0.01      0.03       270
#           28       0.47      0.26      0.34       277
#           29       0.61      0.29      0.39       267
#           30       0.88      0.03      0.05       261
#           31       0.24      0.05      0.08       275
#           32       0.24      0.25      0.25       276
#           33       0.62      0.06      0.11       257
#           34       0.18      0.16      0.17       278
#           35       0.17      0.21      0.19       276
#           36       0.30      0.20      0.24       282
#           37       0.50      0.29      0.37       275
#           38       0.20      0.21      0.20       270
#           39       0.18      0.26      0.21       273
#           40       0.14      0.04      0.06       267
#           41       1.00      0.00      0.01       260
#           42       0.37      0.43      0.40       236
#           43       0.58      0.17      0.26       267
#           44       0.03      0.00      0.01       257
#           45       0.51      0.18      0.27       226
#           46       0.41      0.28      0.33       247
#           47       0.04      0.06      0.05       248
#           48       0.18      0.08      0.11       266
#           49       0.05      0.65      0.09       273
#           50       0.23      0.04      0.07       267
#           51       0.92      1.00      0.96       130
#           52       0.36      0.28      0.32       218
#           53       0.05      0.01      0.01       269
#
#     accuracy                           0.22     14120
#    macro avg       0.35      0.22      0.23     14120
# weighted avg       0.34      0.22      0.22     14120
#
#
#
# Accuracy Score of  SVC() is:
# 0.7625354107648725
# [[251   0   0 ...   0   0   0]
#  [  0 150   0 ...   0   0   0]
#  [  0   0 249 ...   0   0   0]
#  ...
#  [  0   0   0 ... 130   0   0]
#  [  0   0   0 ...   0 215   0]
#  [  0   6   2 ...   0   0 175]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.93      0.68       270
#            1       0.51      0.56      0.53       268
#            2       0.95      0.91      0.93       274
#            3       0.91      0.55      0.69       267
#            4       0.92      0.71      0.80       269
#            5       0.71      0.57      0.63       266
#            6       0.95      0.99      0.97       234
#            7       0.80      0.85      0.83       254
#            8       0.95      0.97      0.96       284
#            9       0.63      0.74      0.68       262
#           10       0.64      0.53      0.58       279
#           11       0.64      0.88      0.74       270
#           12       0.88      0.82      0.85       270
#           13       0.68      0.55      0.61       274
#           14       0.80      0.80      0.80       264
#           15       0.99      0.99      0.99       212
#           16       0.94      0.71      0.81       263
#           17       0.74      0.92      0.82       272
#           18       0.82      0.66      0.73       259
#           19       0.53      0.64      0.58       268
#           20       0.82      0.82      0.82       260
#           21       0.73      0.57      0.64       274
#           22       1.00      0.93      0.96       259
#           23       0.67      0.77      0.72       279
#           24       0.86      0.48      0.62       270
#           25       0.95      0.96      0.96       256
#           26       0.65      0.50      0.56       275
#           27       0.65      0.64      0.65       270
#           28       0.95      0.93      0.94       277
#           29       0.97      0.97      0.97       267
#           30       0.82      0.90      0.86       261
#           31       0.56      0.67      0.61       275
#           32       0.75      0.78      0.77       276
#           33       0.75      0.69      0.72       257
#           34       0.54      0.88      0.67       278
#           35       0.85      0.98      0.91       276
#           36       0.86      0.76      0.81       282
#           37       0.67      0.76      0.71       275
#           38       0.65      0.82      0.73       270
#           39       0.52      0.78      0.63       273
#           40       0.69      0.90      0.78       267
#           41       0.76      0.67      0.71       260
#           42       0.92      0.87      0.89       236
#           43       0.86      0.83      0.85       267
#           44       0.73      0.51      0.60       257
#           45       0.99      0.98      0.99       226
#           46       0.98      0.85      0.91       247
#           47       0.76      0.75      0.76       248
#           48       0.62      0.62      0.62       266
#           49       0.77      0.75      0.76       273
#           50       0.60      0.21      0.31       267
#           51       1.00      1.00      1.00       130
#           52       1.00      0.99      0.99       218
#           53       0.89      0.65      0.75       269
#
#     accuracy                           0.76     14120
#    macro avg       0.78      0.77      0.77     14120
# weighted avg       0.78      0.76      0.76     14120
#
#
#
# Accuracy Score of  DecisionTreeClassifier() is:
# 1.0
# [[270   0   0 ...   0   0   0]
#  [  0 268   0 ...   0   0   0]
#  [  0   0 274 ...   0   0   0]
#  ...
#  [  0   0   0 ... 130   0   0]
#  [  0   0   0 ...   0 218   0]
#  [  0   0   0 ...   0   0 269]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       270
#            1       1.00      1.00      1.00       268
#            2       1.00      1.00      1.00       274
#            3       1.00      1.00      1.00       267
#            4       1.00      1.00      1.00       269
#            5       1.00      1.00      1.00       266
#            6       1.00      1.00      1.00       234
#            7       1.00      1.00      1.00       254
#            8       1.00      1.00      1.00       284
#            9       1.00      1.00      1.00       262
#           10       1.00      1.00      1.00       279
#           11       1.00      1.00      1.00       270
#           12       1.00      1.00      1.00       270
#           13       1.00      1.00      1.00       274
#           14       1.00      1.00      1.00       264
#           15       1.00      1.00      1.00       212
#           16       1.00      1.00      1.00       263
#           17       1.00      1.00      1.00       272
#           18       1.00      1.00      1.00       259
#           19       1.00      1.00      1.00       268
#           20       1.00      1.00      1.00       260
#           21       1.00      1.00      1.00       274
#           22       1.00      1.00      1.00       259
#           23       1.00      1.00      1.00       279
#           24       1.00      1.00      1.00       270
#           25       1.00      1.00      1.00       256
#           26       1.00      1.00      1.00       275
#           27       1.00      1.00      1.00       270
#           28       1.00      1.00      1.00       277
#           29       1.00      1.00      1.00       267
#           30       1.00      1.00      1.00       261
#           31       1.00      1.00      1.00       275
#           32       1.00      1.00      1.00       276
#           33       1.00      1.00      1.00       257
#           34       1.00      1.00      1.00       278
#           35       1.00      1.00      1.00       276
#           36       1.00      1.00      1.00       282
#           37       1.00      1.00      1.00       275
#           38       1.00      1.00      1.00       270
#           39       1.00      1.00      1.00       273
#           40       1.00      1.00      1.00       267
#           41       1.00      1.00      1.00       260
#           42       1.00      1.00      1.00       236
#           43       1.00      1.00      1.00       267
#           44       1.00      1.00      1.00       257
#           45       1.00      1.00      1.00       226
#           46       1.00      1.00      1.00       247
#           47       1.00      1.00      1.00       248
#           48       1.00      1.00      1.00       266
#           49       1.00      1.00      1.00       273
#           50       1.00      1.00      1.00       267
#           51       1.00      1.00      1.00       130
#           52       1.00      1.00      1.00       218
#           53       1.00      1.00      1.00       269
#
#     accuracy                           1.00     14120
#    macro avg       1.00      1.00      1.00     14120
# weighted avg       1.00      1.00      1.00     14120
#
#
#
# Accuracy Score of  KNeighborsClassifier() is:
# 0.8888810198300283
# [[256   0   0 ...   0   0   0]
#  [  0 232   0 ...   0   0   0]
#  [  0   0 270 ...   0   0   0]
#  ...
#  [  0   0   0 ... 130   0   0]
#  [  0   0   0 ...   1 214   0]
#  [  0   4   1 ...   0   0 224]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.86       270
#            1       0.77      0.87      0.81       268
#            2       0.94      0.99      0.96       274
#            3       0.82      0.84      0.83       267
#            4       0.95      0.94      0.95       269
#            5       0.86      0.84      0.85       266
#            6       0.95      0.98      0.97       234
#            7       0.86      0.91      0.89       254
#            8       0.97      0.98      0.97       284
#            9       0.80      0.86      0.83       262
#           10       0.77      0.79      0.78       279
#           11       0.85      0.96      0.90       270
#           12       0.94      0.91      0.92       270
#           13       0.82      0.84      0.83       274
#           14       0.88      0.94      0.91       264
#           15       0.99      0.98      0.98       212
#           16       0.93      0.90      0.91       263
#           17       0.90      0.92      0.91       272
#           18       0.91      0.86      0.89       259
#           19       0.81      0.90      0.85       268
#           20       0.91      0.92      0.91       260
#           21       0.79      0.85      0.82       274
#           22       0.98      0.98      0.98       259
#           23       0.85      0.84      0.85       279
#           24       0.77      0.76      0.77       270
#           25       0.96      0.99      0.97       256
#           26       0.84      0.82      0.83       275
#           27       0.89      0.87      0.88       270
#           28       0.99      0.95      0.97       277
#           29       0.99      0.97      0.98       267
#           30       0.95      0.94      0.95       261
#           31       0.74      0.79      0.76       275
#           32       0.93      0.90      0.91       276
#           33       0.87      0.89      0.88       257
#           34       0.94      0.93      0.94       278
#           35       0.95      0.98      0.96       276
#           36       0.89      0.86      0.88       282
#           37       0.87      0.85      0.86       275
#           38       0.83      0.90      0.87       270
#           39       0.84      0.82      0.83       273
#           40       0.87      0.91      0.89       267
#           41       0.87      0.85      0.86       260
#           42       0.95      0.92      0.94       236
#           43       0.95      0.85      0.90       267
#           44       0.91      0.82      0.86       257
#           45       0.99      0.97      0.98       226
#           46       0.98      0.96      0.97       247
#           47       0.91      0.77      0.84       248
#           48       0.93      0.80      0.86       266
#           49       0.89      0.88      0.88       273
#           50       0.76      0.59      0.67       267
#           51       0.99      1.00      1.00       130
#           52       0.99      0.98      0.98       218
#           53       0.96      0.83      0.89       269
#
#     accuracy                           0.89     14120
#    macro avg       0.89      0.89      0.89     14120
# weighted avg       0.89      0.89      0.89     14120

# %%
# here above we can find the accuracy score for the following ML-MOdels is :
# accuracy score for LogisticRegression() =51 %
# accuracy score for GaussianNB() = 22 %
# accuracy score for SVC() = 76 %
# accuracy score for DecisionTreeClassifier() = 100 %
# accuracy score for KNeighborsClassifier() = 89 %

#  here above we can see that the SVC(), DTC(), & KNN() MODELS are working good as compared to other model.
# dtc & knn is best performing models, out of this dtc is perrforming good
# therefore we can decide DTC model has to apply as a FINAL MODEL.

# %%
final_model = DecisionTreeClassifier()

# %%
final_model.fit(x_train,y_train)
final_model.score(x_train,y_train)
final_model_pred = final_model.predict(x_test)
print(accuracy_score(y_test,final_model_pred))
print(confusion_matrix(y_test,final_model_pred))
print(classification_report(y_test,final_model_pred))

# here DECISION TREE CLASSIFIER as FINAL MODEL with ACCURACY OF = 81 %
# Out:
# 0.8014726706315491
# [[51  0  0 ...  0  0  0]
#  [ 0 50  0 ...  0  0  3]
#  [ 0  0 56 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 38  0  0]
#  [ 0  0  0 ...  1 36  0]
#  [ 0  1  1 ...  0  0 41]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.77        68
#            1       0.74      0.72      0.73        69
#            2       0.92      0.88      0.90        64
#            3       0.82      0.87      0.84        62
#            4       0.90      0.91      0.91        69
#            5       0.76      0.75      0.76        72
#            6       0.93      0.95      0.94        56
#            7       0.90      0.81      0.85        78
#            8       0.91      0.94      0.93        54
#            9       0.86      0.67      0.76        76
#           10       0.80      0.69      0.75        59
#           11       0.86      0.82      0.84        68
#           12       0.83      0.85      0.84        68
#           13       0.71      0.77      0.74        64
#           14       0.88      0.82      0.85        72
#           15       0.93      0.93      0.93        60
#           16       0.87      0.89      0.88        75
#           17       0.88      0.83      0.85        59
#           18       0.80      0.85      0.82        79
#           19       0.78      0.86      0.82        70
#           20       0.78      0.82      0.80        77
#           21       0.62      0.75      0.68        59
#           22       0.93      0.90      0.92        72
#           23       0.66      0.69      0.68        59
#           24       0.60      0.55      0.58        65
#           25       0.96      0.95      0.95        77
#           26       0.64      0.71      0.68        63
#           27       0.79      0.78      0.79        68
#           28       0.83      0.83      0.83        60
#           29       0.91      0.84      0.88        58
#           30       0.96      0.88      0.92        77
#           31       0.60      0.67      0.63        60
#           32       0.81      0.81      0.81        62
#           33       0.73      0.77      0.75        79
#           34       0.82      0.70      0.76        60
#           35       0.86      0.92      0.89        62
#           36       0.76      0.73      0.74        48
#           37       0.72      0.81      0.76        53
#           38       0.83      0.88      0.86        68
#           39       0.69      0.77      0.73        65
#           40       0.82      0.87      0.85        69
#           41       0.76      0.79      0.77        76
#           42       0.90      0.94      0.92        65
#           43       0.71      0.71      0.71        59
#           44       0.85      0.78      0.81        81
#           45       0.87      0.91      0.89        66
#           46       0.91      0.87      0.89        60
#           47       0.81      0.72      0.76        80
#           48       0.66      0.64      0.65        67
#           49       0.72      0.80      0.76        65
#           50       0.50      0.45      0.47        69
#           51       0.97      0.97      0.97        39
#           52       0.95      0.95      0.95        38
#           53       0.64      0.65      0.65        63
#
#     accuracy                           0.80      3531
#    macro avg       0.80      0.80      0.80      3531
# weighted avg       0.80      0.80      0.80      3531

# %%
xf2.shape
# Out:
# (17651, 9)

# %%
def pred_func(dt):
    dt= dt.reshape(1,9)
    region = final_model.predict(dt)
    print(region)
    
    if region == 0:
        print("Albay")
    elif (region == 1):
        print ("Atlanta")
    elif (region == 2):
        print ("Baltimore Washingtone")
    elif (region == 3):
        print ("Bois")
    elif (region == 4):
        print ("Boston")
    elif (region == 5):
        print ("BuffaloRochester")
    elif (region == 6):
        print("California")
    elif (region == 7):
        print ("Charllote")
    elif (region == 8):
        print ("Chicago")
    elif (region == 9):
        print ("Cincinnati")
    elif (region == 10):
        print ("Columbus")
    elif (region == 11):
        print ("DallaFTWorth")
    elif (region == 12):
        print ("Denver")
    elif (region ==13):
        print ("Datroit")
    elif (region == 14):
        print ("Grandrapids")
    elif (region == 15):
        print ("GreatLakes")
    elif (region == 16):
        print ("Harrisburg")
    elif (region == 17):
        print ("HartFord")
    elif (region == 18):
        print ("Huston")
    elif (region == 19):
        print ("IndianaPolis")
    elif (region == 20):
        print ("Jaksonville")
    elif (region == 21):
        print ("Lasvegas")
    elif (region == 22):
        print ("Losangeles")
    elif (region == 23):
        print ("Louisville")
    elif (region == 24):
        print ("Miami")
    elif (region == 25):
        print ("Midsouth")
    elif (region == 26):
        print ("Nashville")
    elif (region == 27):
        print ("Neworleans")
    elif (region == 28):
        print ("Newyork")
    elif (region == 29):
        print ("Northeast")
    elif (region == 30):
        print ("NothernNewEngland")
    elif (region == 31):
        print ("Orland")
    elif (region == 32):
        print ("Philadeplphia")
    elif (region == 33):
        print ("Phoenix")
    elif (region == 34):
        print ("Pittsburg")
    elif (region == 35):
        print ("Plains")
    elif (region == 36):
        print ("Portlands")
    elif (region == 37):
        print ("Ralaighgreenboro")
    elif (region == 38):
        print ("Richmond")
    elif (region == 39):
        print ("Roanoke")
    elif (region == 40):
        print ("Scaramento")
    elif (region == 41):
        print ("Sandiago")
    elif (region == 42):
        print ("Sanfrancisko")
    elif (region == 43):
        print ("Seattle")
    elif (region == 44):
        print ("SouthCalofornia")
    elif (region == 45):
        print ("SouthCentral")
    elif (region == 46):
        print ("SouthEast")
    elif (region == 47):
        print ("Spokane")
    elif (region == 48):
        print ("StLouis")
    elif (region == 49):
        print ("Syracus")
    elif (region == 50):
        print ("tempa")
    elif (region == 51):
        print ("WestexNewMaxico")
    elif (region == 52):
        print ("TotalUS")
    elif (region == 53):
        print ("West")
    else:
        print('Not Found')
# making 'def' function to predict REGION for Avocado.

# %%
# TEST SAMPLE-1 ====>>

# %%
xf2.head(1)
# Out:
#    average price      4046      4225     4770  small bags  large bags  \
# 0      -0.195352 -0.709648  0.059642 -0.53397   -0.517773   -0.796802
#
#    xlarge bags      type      year
# 0     -0.51836 -1.019047 -1.210013

# %%
dt= np.array([-0.195352,-0.709648,0.059642,-0.53397,-0.517773,-0.796802,-0.51836,-1.019047,-1.210013])
pred_func(dt)

#  data taken from position 'xf2.head(1)'
# here the ATUAL REGION GIVEN DATA IS = ALBAY
#       & THE PREDICTED REGION BY MODEL IS = ALBAY
# Out:
# [0]
# Albay

# %%
# TEST SAMPLE-2 ====>>

# %%
xf2.tail(1)
# Out:
#        average price      4046      4225      4770  small bags  large bags  \
# 17650       0.556367 -0.570892 -0.802154 -0.352835   -0.413625   -0.889294
#
#        xlarge bags      type      year
# 17650     -0.51836  0.981309  1.980756

# %%
dt= np.array([0.556367,-0.570892,-0.802154,-0.352835,-0.413625,-0.889294,-0.51836,0.981309,1.980756])
pred_func(dt)

#  data taken from position 'xf2.tail(1)'
# here the ATUAL REGION GIVEN DATA IS = WEST
#       & THE PREDICTED REGION BY MODEL IS = WEST
# Out:
# [53]
# West

# %%
# TEST SAMPLE-3 ====>>

# %%
# xf2.sample(1)

# %%
dt= np.array([-0.610094,0.726759,0.785801,1.121468,0.221783,-0.708166,-0.293617,-1.019047,-1.210013])
pred_func(dt)

#  data taken from 1884th position 'xf2.sample(1)'
# here the ATUAL REGION GIVEN DATA IS = Portlands
#       & THE PREDICTED REGION BY MODEL IS = Portlands
# Out:
# [36]
# Portlands

# %%
# HERE ABOVE IN ALL TEST THREE SAMPLES , MODEL PRICTING REGION ACCURATELY

# %% [markdown]
# SAVING MODEL ===================================================================================================================

# %%
import pickle

# %%
file_name = 'avocado_region_identification.pkl' 
pickle.dump(final_model,open(file_name,'wb'))

# %% [markdown]
# ========================================  FINISHED ================================================
